# %% [markdown]
# # Survivability of ICU Patients with Severe Sepsis Shock

# %% [markdown]
# Although U.S. hospitals pay out over $22.2 billion annually for sepsis treatment, the disease still causes 20-45 percent of death in hospitals. By the time the physical manifestations of sepsis start to appear, it’s sometimes too late to help the patient. Somewhere, buried in the data – in the blood values, the blood-pressure values, the heart rate, the temperature – is a prediction that this patient is heading toward an overwhelming infection and is likely to die. If we could predict that very early, it will make it less likely the patient would die.
#
# A predictive model that determines which patients are most vulnerable can really help ICUs focus their Physicians and staff on the most vulnerable patients. Potentially, such selective treatment can reduce mortality without increasing spending. Through this Notebook, a machine learning model is being designed to predict death within 30 days of ICU admission for the patients who have been diagnosed with Sepsis/septic shock.

# %%
# Importing sqlalchemy to run SQL queries against MIMIC-III Postgres database
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, MetaData
import sqlalchemy

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import datetime

import seaborn as sns
sns.set(style='ticks')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sqlalchemy.__version__
# Out:
# '1.0.11'

# %%
# Defining connection to Postgres database
# Set up SQL Alchemy engine and session
# commenting userid, password and actual instance
engine = create_engine("postgresql://********:*************@*******.*********.us-west-2.rds.amazonaws.com:5432/********")
m = MetaData(schema="mimiciii")


Base = automap_base(bind=engine, metadata=m)
Base.prepare(engine, reflect=True)

# For patient's admission, vitals and infection information, Classes are being created.
# Classes are mapped to the appropriate tables in Postgres.
Admission = Base.classes.admissions
Patient = Base.classes.patients
LabEvent = Base.classes.labevents
BioEvent = Base.classes.microbiologyevents

session = Session(engine)

# %% [markdown]
# Admissions table is being queried to get admissions for all the patients who have been diagnosed with Sepsis.

# %%
admission_query = session.query(Admission).filter_by(diagnosis='SEPSIS')

df = pd.read_sql(admission_query.statement, admission_query.session.bind)

df.head()
# Out:
#    row_id  subject_id  hadm_id           admittime           dischtime  \
# 0     458         357   122609 2198-11-01 22:36:00 2198-11-14 14:20:00
# 1     471         366   134462 2164-11-18 20:27:00 2164-11-22 15:18:00
# 2      96          94   183686 2176-02-25 16:49:00 2176-02-29 17:45:00
# 3      20          21   111970 2135-01-30 20:50:00 2135-02-08 02:08:00
# 4     448         353   108923 2151-03-28 16:01:00 2151-04-13 16:10:00
#
#              deathtime admission_type    admission_location  \
# 0                 None      EMERGENCY  EMERGENCY ROOM ADMIT
# 1                 None      EMERGENCY  EMERGENCY ROOM ADMIT
# 2                 None      EMERGENCY  EMERGENCY ROOM ADMIT
# 3  2135-02-08 02:08:00      EMERGENCY  EMERGENCY ROOM ADMIT
# 4                 None      EMERGENCY  EMERGENCY ROOM ADMIT
#
#          discharge_location insurance language       religion marital_status  \
# 0  REHAB/DISTINCT PART HOSP   Private     ENGL  NOT SPECIFIED        MARRIED
# 1          HOME HEALTH CARE  Medicare     ENGL       CATHOLIC         SINGLE
# 2          HOME HEALTH CARE  Medicare     CANT  NOT SPECIFIED        MARRIED
# 3              DEAD/EXPIRED  Medicare     None         JEWISH        MARRIED
# 4                      HOME  Medicare     PTUN         JEWISH         SINGLE
#
#             ethnicity           edregtime           edouttime diagnosis  \
# 0               WHITE 2198-11-01 18:01:00 2198-11-01 23:06:00    SEPSIS
# 1  HISPANIC OR LATINO 2164-11-18 10:52:00 2164-11-18 21:31:00    SEPSIS
# 2               ASIAN 2176-02-25 10:35:00 2176-02-25 18:14:00    SEPSIS
# 3               WHITE 2135-01-30 18:46:00 2135-01-30 22:05:00    SEPSIS
# 4               WHITE 2151-03-28 13:02:00 2151-03-28 17:46:00    SEPSIS
#
#    hospital_expire_flag  has_chartevents_data
# 0                     0                     1
# 1                     0                     1
# 2                     0                     1
# 3                     1                     1
# 4                     0                     1

# %%
df['admission_location'].unique()
# Out:
# array([u'EMERGENCY ROOM ADMIT', u'CLINIC REFERRAL/PREMATURE',
#        u'TRANSFER FROM HOSP/EXTRAM', u'TRANSFER FROM SKILLED NUR',
#        u'PHYS REFERRAL/NORMAL DELI', u'TRANSFER FROM OTHER HEALT'], dtype=object)

# %% [markdown]
# For each of the admission, we will check if patient died within 30 days. If the patient dies within 30 days, we will flag that row. This flag will be used to determine outcome for Machine Learning models.
#
# Note that we are not using hospital_expire_flag as that includes the patients who died past 30 days.

# %%
def period(row, period):
    
    if row['deathtime'] == None:
        return 0
    elif row['deathtime'] - row['admittime'] > period:
        return 0
    else:
        return 1

df['death_within_30_days'] = df.apply (lambda row: period (row, pd.Timedelta('30 days')),axis=1)

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %%
df.death_within_30_days.value_counts().plot.pie(autopct=make_autopct(df.death_within_30_days.value_counts()),startangle = 180,colormap='Pastel2')

# %%
df.religion.value_counts()
# Out:
# CATHOLIC                  431
# NOT SPECIFIED             208
# JEWISH                    160
# PROTESTANT QUAKER         156
# UNOBTAINABLE              112
# OTHER                      61
# EPISCOPALIAN               17
# GREEK ORTHODOX             10
# BUDDHIST                    6
# JEHOVAH'S WITNESS           5
# CHRISTIAN SCIENTIST         5
# MUSLIM                      4
# ROMANIAN EAST. ORTH         2
# UNITARIAN-UNIVERSALIST      1
# 7TH DAY ADVENTIST           1
# HINDU                       1
# Name: religion, dtype: int64

# %%
df.columns
# Out:
# Index([              u'row_id',           u'subject_id',
#                     u'hadm_id',            u'admittime',
#                   u'dischtime',            u'deathtime',
#              u'admission_type',   u'admission_location',
#          u'discharge_location',            u'insurance',
#                    u'language',             u'religion',
#              u'marital_status',            u'ethnicity',
#                   u'edregtime',            u'edouttime',
#                   u'diagnosis', u'hospital_expire_flag',
#        u'has_chartevents_data', u'death_within_30_days'],
#       dtype='object')

# %% [markdown]
# ### Filtering out the columns that may impact the survivality.
#
# Keeping the time of admission as it will be needed later to calculate age at the time of admission. Dropping following columns (as they will have either no impact or minimal impact on survivalibility) -
#
# 1. dischtime
# 2. deathtime
# 3. admission_location
# 4. discharce_location
# 5. language - ethinicity is included if there is a variation based upon origin/race of the person.
# 6. religion - ethinicity is included if there is a variation based upon origin/race of the person.
# 7. marital_status
# 8. edregtime
# 9. edouttime
# 10. diagnosis (only sepsis customers are there in this DB)
# 11. hospital_expire_flag
#
#
# Religion and Language may have impact, but it very unlikely. Ethinicy is more important, so keeping the ethnicity column.

# %%
admission_columns = ['subject_id', 'hadm_id', 'admittime', 'admission_type', 'insurance', 'ethnicity', 'death_within_30_days']
admissions = df[admission_columns]
admissions.head()
# Out:
#    subject_id  hadm_id           admittime admission_type insurance  \
# 0         357   122609 2198-11-01 22:36:00      EMERGENCY   Private
# 1         366   134462 2164-11-18 20:27:00      EMERGENCY  Medicare
# 2          94   183686 2176-02-25 16:49:00      EMERGENCY  Medicare
# 3          21   111970 2135-01-30 20:50:00      EMERGENCY  Medicare
# 4         353   108923 2151-03-28 16:01:00      EMERGENCY  Medicare
#
#             ethnicity  death_within_30_days
# 0               WHITE                     0
# 1  HISPANIC OR LATINO                     0
# 2               ASIAN                     0
# 3               WHITE                     1
# 4               WHITE                     0

# %% [markdown]
# #### Get Patient information

# %%
patient_query = session.query(Patient)
patients = pd.read_sql(patient_query.statement, patient_query.session.bind)
patients.head()
# Out:
#    row_id  subject_id gender        dob        dod   dod_hosp dod_ssn  \
# 0     234         249      F 2075-03-13        NaT        NaT    None
# 1     235         250      F 2164-12-27 2188-11-22 2188-11-22    None
# 2     236         251      M 2090-03-15        NaT        NaT    None
# 3     237         252      M 2078-03-06        NaT        NaT    None
# 4     238         253      F 2089-11-26        NaT        NaT    None
#
#    expire_flag
# 0            0
# 1            1
# 2            0
# 3            0
# 4            0

# %% [markdown]
# Trimming the fields that has no impact on survivavility of Sepsis patients.

# %%
patients = patients[['subject_id', 'gender', 'dob']]

# %% [markdown]
# Joining patients and admission data into a single data frame

# %%
patient_and_admission_data = admissions.join(patients.set_index('subject_id'), on='subject_id')
patient_and_admission_data.head()
# Out:
#    subject_id  hadm_id           admittime admission_type insurance  \
# 0         357   122609 2198-11-01 22:36:00      EMERGENCY   Private
# 1         366   134462 2164-11-18 20:27:00      EMERGENCY  Medicare
# 2          94   183686 2176-02-25 16:49:00      EMERGENCY  Medicare
# 3          21   111970 2135-01-30 20:50:00      EMERGENCY  Medicare
# 4         353   108923 2151-03-28 16:01:00      EMERGENCY  Medicare
#
#             ethnicity  death_within_30_days gender        dob
# 0               WHITE                     0      M 2135-03-22
# 1  HISPANIC OR LATINO                     0      M 2112-05-22
# 2               ASIAN                     0      M 2101-09-20
# 3               WHITE                     1      M 2047-04-04
# 4               WHITE                     0      M 2089-07-23

# %% [markdown]
# #### Calculate the age of patient at the time of admission.
#
# Using adminttime and dob, patient's age is calculated at the time of admission to hospital.
#
# **Note:** Patients who are older than 89 years old at any time in the database have had their date of birth shifted to obscure their age and comply with HIPAA. The shift process was as follows: the patient’s age at their first admission was determined. The date of birth was then set to exactly 300 years before their first admission. Since median age of such patient was 91.4, I am setting up age of such patient as 91

# %%
def calculate_age(row):
    age = int((row['admittime'] - row['dob'])/pd.Timedelta('365 days'))   
    if age < 0:
        age = 91
    return age
patient_and_admission_data['age'] = patient_and_admission_data.apply(lambda row: calculate_age (row),axis=1)
patient_and_admission_data.head()
# Out:
#    subject_id  hadm_id           admittime admission_type insurance  \
# 0         357   122609 2198-11-01 22:36:00      EMERGENCY   Private
# 1         366   134462 2164-11-18 20:27:00      EMERGENCY  Medicare
# 2          94   183686 2176-02-25 16:49:00      EMERGENCY  Medicare
# 3          21   111970 2135-01-30 20:50:00      EMERGENCY  Medicare
# 4         353   108923 2151-03-28 16:01:00      EMERGENCY  Medicare
#
#             ethnicity  death_within_30_days gender        dob  age
# 0               WHITE                     0      M 2135-03-22   63
# 1  HISPANIC OR LATINO                     0      M 2112-05-22   52
# 2               ASIAN                     0      M 2101-09-20   74
# 3               WHITE                     1      M 2047-04-04   87
# 4               WHITE                     0      M 2089-07-23   61

# %% [markdown]
# ## Analyze patients basic data to understand the impact on survivavility

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %% [markdown]
# ** Number and percentage of customers by age **

# %%
patient_and_admission_data.age.value_counts().sort_index().plot(kind='bar', figsize=(20, 10),stacked=True, colormap='Paired')

# %% [markdown]
# ** Number of patients by age groups **
#
# Patients have been broken into 5 categories - 0 to 20 years, 20 to 40 years, 40 to 60 years, 60 to 80 years and 80 to 100 years. Below chart shows number of patients by each age group in the dataset.

# %%
bins = [0, 20, 40, 60, 80, 100]
patient_and_admission_data['age_bins'] = pd.cut(patient_and_admission_data['age'], bins)
patient_and_admission_data.age_bins.value_counts().sort_index().plot(kind='bar', figsize=(15, 10),stacked=True, colormap='Paired')

# %% [markdown]
# ** Survival or Death of customers by age group**
#
# Since there are different number of customers in each age group, I will show the survival and death by both numbers and percentage such that we can truly compare the data.

# %%
death_within_30_days_by_agegroup = patient_and_admission_data.groupby(['age_bins','death_within_30_days'])['age_bins'].count()
death_within_30_days_by_agegroup
# Out:
# age_bins   death_within_30_days
# (0, 20]    0                         6
# (20, 40]   0                        72
#            1                         9
# (40, 60]   0                       241
#            1                        52
# (60, 80]   0                       413
#            1                       111
# (80, 100]  0                       199
#            1                        80
# Name: age_bins, dtype: int64

# %%
g = sns.factorplot("age_bins", hue="death_within_30_days",data=patient_and_admission_data, kind="count", size=5, aspect=2)

# %%
percent_death_within_30_days_by_agegroup=pd.DataFrame(death_within_30_days_by_agegroup.groupby(level=[0]).apply(lambda x: x*100 / x.sum()))
percent_death_within_30_days_by_agegroup.reset_index(inplace=True)
percent_death_within_30_days_by_agegroup.rename(columns={0: 'Percent'}, inplace=True)
percent_death_within_30_days_by_agegroup
# Out:
#     age_bins  death_within_30_days     Percent
# 0    (0, 20]                     0  100.000000
# 1   (20, 40]                     0   88.888889
# 2   (20, 40]                     1   11.111111
# 3   (40, 60]                     0   82.252560
# 4   (40, 60]                     1   17.747440
# 5   (60, 80]                     0   78.816794
# 6   (60, 80]                     1   21.183206
# 7  (80, 100]                     0   71.326165
# 8  (80, 100]                     1   28.673835

# %%
g = sns.factorplot(x="age_bins", y="Percent", hue="death_within_30_days",
...                    data=percent_death_within_30_days_by_agegroup, saturation=.5,
...                    kind="bar", ci=8, aspect=2)
g.set(ylim=(0,100))

# %% [markdown]
# As the age goes up, it appears that percentage of death goes up.

# %% [markdown]
# ** Number and Percentage of customers by Gender in the dataset **

# %%
patient_and_admission_data.gender.value_counts().plot(kind='pie',autopct=make_autopct(patient_and_admission_data.gender.value_counts()),startangle = 180, subplots=True,colormap='Pastel2')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9b56b9a50>], dtype=object)

# %% [markdown]
# ** Survival Count by Gender in the dataset **

# %%
death_within_30_days_by_gender = patient_and_admission_data[['gender','death_within_30_days']].groupby(['death_within_30_days','gender'])['gender'].count()

# %%
death_within_30_days_by_gender.describe
# Out:
# <bound method Series.describe of death_within_30_days  gender
# 0                     F         432
#                       M         500
# 1                     F         107
#                       M         145
# Name: gender, dtype: int64>

# %%
g = sns.factorplot("gender", hue="death_within_30_days",data=patient_and_admission_data, kind="count", size=5, aspect=2)

# %% [markdown]
# ** Survival and Death by percentage across both genders **
#
# **Note** - Perecentage wise, it appears that death because of Sepsis is same across both genders.

# %%
percent_death_within_30_days_by_gender=pd.DataFrame(death_within_30_days_by_gender.groupby(level=[1]).apply(lambda x: x*100 / x.sum()))
percent_death_within_30_days_by_gender.reset_index(inplace=True)
percent_death_within_30_days_by_gender.rename(columns={0: 'Percent'}, inplace=True)
percent_death_within_30_days_by_gender
# Out:
#    death_within_30_days gender    Percent
# 0                     0      F  80.148423
# 1                     0      M  77.519380
# 2                     1      F  19.851577
# 3                     1      M  22.480620

# %%
g = sns.factorplot(x="gender", y="Percent", hue="death_within_30_days",
...                    data=percent_death_within_30_days_by_gender, saturation=.5,
...                    kind="bar", ci=8, aspect=2)
g.set(ylim=(0,100))

# %% [markdown]
# **Number and Percentage of customers by Insurance in the dataset**

# %%
#patient_and_admission_data.insurance.value_counts().plot(kind='pie',autopct=make_autopct(patient_and_admission_data.insurance.value_counts()),startangle = 90, subplots=True,colormap='Pastel2')
patient_and_admission_data.insurance.value_counts().plot(kind='pie',autopct=make_autopct(patient_and_admission_data.insurance.value_counts()),subplots=True,colormap='Paired')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9b4527590>], dtype=object)

# %% [markdown]
# ** Survival and Death by percentage across the insurance in the dataset**

# %%
death_within_30_days_by_insurance = patient_and_admission_data.groupby(['insurance','death_within_30_days'])['gender'].count()

# %%
death_within_30_days_by_insurance
# Out:
# insurance   death_within_30_days
# Government  0                        14
#             1                         4
# Medicaid    0                        74
#             1                        20
# Medicare    0                       625
#             1                       189
# Private     0                       213
#             1                        36
# Self Pay    0                         6
#             1                         3
# Name: gender, dtype: int64

# %%
percent_death_within_30_days_by_insurance=pd.DataFrame(death_within_30_days_by_insurance.groupby(level=[0]).apply(lambda x: x*100 / x.sum()))
percent_death_within_30_days_by_insurance.reset_index(inplace=True)
percent_death_within_30_days_by_insurance.rename(columns={0: 'Percent'}, inplace=True)
percent_death_within_30_days_by_insurance
# Out:
#     insurance  death_within_30_days    Percent
# 0  Government                     0  77.777778
# 1  Government                     1  22.222222
# 2    Medicaid                     0  78.723404
# 3    Medicaid                     1  21.276596
# 4    Medicare                     0  76.781327
# 5    Medicare                     1  23.218673
# 6     Private                     0  85.542169
# 7     Private                     1  14.457831
# 8    Self Pay                     0  66.666667
# 9    Self Pay                     1  33.333333

# %%
g = sns.factorplot(x="insurance", y="Percent", hue="death_within_30_days",
...                    data=percent_death_within_30_days_by_insurance, saturation=.5,
...                    kind="bar", ci=8, aspect=2)
g.set(ylim=(0,100))

# %% [markdown]
# **Number and Percentage of customers by Ethnicity in the dataset**

# %%
patient_and_admission_data.ethnicity.value_counts().plot(kind='bar',figsize=(15, 10), subplots=True,colormap='Paired')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9b36c82d0>], dtype=object)

# %%
death_within_30_days_by_ethnicity = patient_and_admission_data.groupby(['ethnicity','death_within_30_days'])['ethnicity'].count()
death_within_30_days_by_ethnicity
# Out:
# ethnicity                       death_within_30_days
# ASIAN                           0                        15
#                                 1                         4
# ASIAN - ASIAN INDIAN            0                         2
# ASIAN - CAMBODIAN               0                         3
# ASIAN - CHINESE                 0                         6
#                                 1                         4
# ASIAN - KOREAN                  0                         1
# ASIAN - VIETNAMESE              0                         1
# BLACK/AFRICAN                   1                         1
# BLACK/AFRICAN AMERICAN          0                       111
#                                 1                        26
# BLACK/CAPE VERDEAN              0                         2
#                                 1                         1
# BLACK/HAITIAN                   0                         5
# HISPANIC OR LATINO              0                        23
#                                 1                         5
# HISPANIC/LATINO - CUBAN         0                         1
# HISPANIC/LATINO - MEXICAN       0                         1
# HISPANIC/LATINO - PUERTO RICAN  0                         7
# MULTI RACE ETHNICITY            0                         2
# OTHER                           0                        14
#                                 1                         4
# PATIENT DECLINED TO ANSWER      0                         2
#                                 1                         1
# PORTUGUESE                      0                         2
# UNABLE TO OBTAIN                0                         6
#                                 1                         2
# UNKNOWN/NOT SPECIFIED           0                        42
#                                 1                        18
# WHITE                           0                       678
#                                 1                       186
# WHITE - BRAZILIAN               0                         1
# WHITE - EASTERN EUROPEAN        0                         2
# WHITE - OTHER EUROPEAN          0                         1
# WHITE - RUSSIAN                 0                         4
# Name: ethnicity, dtype: int64

# %%
percent_death_within_30_days_by_ethnicity=pd.DataFrame(death_within_30_days_by_ethnicity.groupby(level=[0]).apply(lambda x: x*100 / x.sum()))
percent_death_within_30_days_by_ethnicity.reset_index(inplace=True)
percent_death_within_30_days_by_ethnicity.rename(columns={0: 'Percent'}, inplace=True)
percent_death_within_30_days_by_ethnicity
# Out:
#                          ethnicity  death_within_30_days     Percent
# 0                            ASIAN                     0   78.947368
# 1                            ASIAN                     1   21.052632
# 2             ASIAN - ASIAN INDIAN                     0  100.000000
# 3                ASIAN - CAMBODIAN                     0  100.000000
# 4                  ASIAN - CHINESE                     0   60.000000
# 5                  ASIAN - CHINESE                     1   40.000000
# 6                   ASIAN - KOREAN                     0  100.000000
# 7               ASIAN - VIETNAMESE                     0  100.000000
# 8                    BLACK/AFRICAN                     1  100.000000
# 9           BLACK/AFRICAN AMERICAN                     0   81.021898
# 10          BLACK/AFRICAN AMERICAN                     1   18.978102
# 11              BLACK/CAPE VERDEAN                     0   66.666667
# 12              BLACK/CAPE VERDEAN                     1   33.333333
# 13                   BLACK/HAITIAN                     0  100.000000
# 14              HISPANIC OR LATINO                     0   82.142857
# 15              HISPANIC OR LATINO                     1   17.857143
# 16         HISPANIC/LATINO - CUBAN                     0  100.000000
# 17       HISPANIC/LATINO - MEXICAN                     0  100.000000
# 18  HISPANIC/LATINO - PUERTO RICAN                     0  100.000000
# 19            MULTI RACE ETHNICITY                     0  100.000000
# 20                           OTHER                     0   77.777778
# 21                           OTHER                     1   22.222222
# 22      PATIENT DECLINED TO ANSWER                     0   66.666667
# 23      PATIENT DECLINED TO ANSWER                     1   33.333333
# 24                      PORTUGUESE                     0  100.000000
# 25                UNABLE TO OBTAIN                     0   75.000000
# 26                UNABLE TO OBTAIN                     1   25.000000
# 27           UNKNOWN/NOT SPECIFIED                     0   70.000000
# 28           UNKNOWN/NOT SPECIFIED                     1   30.000000
# 29                           WHITE                     0   78.472222
# 30                           WHITE                     1   21.527778
# 31               WHITE - BRAZILIAN                     0  100.000000
# 32        WHITE - EASTERN EUROPEAN                     0  100.000000
# 33          WHITE - OTHER EUROPEAN                     0  100.000000
# 34                 WHITE - RUSSIAN                     0  100.000000

# %%
fig,ax = plt.subplots(figsize=(20,10))
fig.autofmt_xdate(rotation=90)
g = sns.factorplot(x="ethnicity", y="Percent", hue="death_within_30_days", data=percent_death_within_30_days_by_ethnicity, kind="bar", ax=ax)
g.set(ylim=(0,100))
ax.legend(bbox_to_anchor=(1, 1), loc=2)
plt.close(2)

# %% [markdown]
# ## Retreive and Analyze patients vital data within 24 hours of admission

# %% [markdown]
# #### Retreive lab events (or vitals) for all Sepsis patients hospital admission

# %%
patient_hadm_ids = patient_and_admission_data.hadm_id.tolist()
lab_event_query = session.query(LabEvent).filter(LabEvent.hadm_id.in_(patient_hadm_ids))
lab_events = pd.read_sql(lab_event_query.statement, lab_event_query.session.bind)

# %% [markdown]
# #### Merging Patients demographic, adminission and lab data together

# %%
columns_to_keep = ['subject_id','hadm_id','admittime', 'admission_type','ethnicity','death_within_30_days','gender','age']
patient_lab_and_admission_data = patient_and_admission_data[columns_to_keep]
patient_lab_and_admission_data=pd.merge(lab_events,patient_lab_and_admission_data,how='left',on=['subject_id','hadm_id'])
patient_lab_and_admission_data.shape
# Out:
# (625316, 15)

# %% [markdown]
# #### Filtering out all vital information capture 24 hours after the patient was admitted
#
# Note that we are predicting the patient's survivality within 24 hours of admission. So, we will use only the data that was captured before 24 hours of hospital admission.

# %%
patient_lab_and_admission_data = patient_lab_and_admission_data[(patient_lab_and_admission_data['charttime'] - patient_lab_and_admission_data['admittime'] < pd.Timedelta('1 days'))]
patient_lab_and_admission_data.reset_index(inplace=True)
patient_lab_and_admission_data.shape
# Out:
# (178420, 16)

# %% [markdown]
# #### Getting corresponding lab items for all the lab events
#
# This is jut to get the label, fluid and category of each lab item

# %%
lab_items.columns
# Out:
# Index([u'itemid', u'label', u'fluid'], dtype='object')

# %%
lab_event_id = patient_lab_and_admission_data['itemid'].unique().tolist()
d_labitems = Base.classes.d_labitems
d_labitems_query = session.query(d_labitems).filter(d_labitems.itemid.in_(lab_event_id))
lab_items = pd.read_sql(d_labitems_query.statement, d_labitems_query.session.bind)
lab_items.drop(['row_id','category','loinc_code'],axis=1,inplace=True)
lab_items.head()
# Out:
#    itemid                                label  fluid
# 0   50800                        SPECIMEN TYPE  BLOOD
# 1   50801           Alveolar-arterial Gradient  Blood
# 2   50802                          Base Excess  Blood
# 3   50803  Calculated Bicarbonate, Whole Blood  Blood
# 4   50804                 Calculated Total CO2  Blood

# %% [markdown]
# Merge lab item with Patient's admission and vital information

# %%
patient_lab_and_admission_data = pd.merge(patient_lab_and_admission_data,lab_items,how='left',on=['itemid'])
# Out:
# (178420, 18)

# %%
patient_lab_and_admission_data.head()
# Out:
#    index  row_id  subject_id  hadm_id  itemid           charttime value  \
# 0      2  430127         652   100262   50802 2142-04-28 04:15:00   -14
# 1      3  430128         652   100262   50804 2142-04-28 04:15:00    16
# 2      4  430129         652   100262   50818 2142-04-28 04:15:00    47
# 3      5  430130         652   100262   50820 2142-04-28 04:15:00  7.11
# 4      6  430131         652   100262   50821 2142-04-28 04:15:00   116
#
#    valuenum valueuom      flag           admittime admission_type  \
# 0    -14.00    mEq/L      None 2142-04-28 04:40:00      EMERGENCY
# 1     16.00    mEq/L  abnormal 2142-04-28 04:40:00      EMERGENCY
# 2     47.00    mm Hg  abnormal 2142-04-28 04:40:00      EMERGENCY
# 3      7.11    units  abnormal 2142-04-28 04:40:00      EMERGENCY
# 4    116.00    mm Hg  abnormal 2142-04-28 04:40:00      EMERGENCY
#
#                 ethnicity  death_within_30_days gender  age  \
# 0  BLACK/AFRICAN AMERICAN                     0      M   21
# 1  BLACK/AFRICAN AMERICAN                     0      M   21
# 2  BLACK/AFRICAN AMERICAN                     0      M   21
# 3  BLACK/AFRICAN AMERICAN                     0      M   21
# 4  BLACK/AFRICAN AMERICAN                     0      M   21
#
#                   label  fluid
# 0           Base Excess  Blood
# 1  Calculated Total CO2  Blood
# 2                  pCO2  Blood
# 3                    pH  Blood
# 4                   pO2  Blood

# %% [markdown]
# Cleaning up Patient lab and admission data to get rid of unnecessary columns

# %%
patient_lab_and_admission_data.drop(['index','row_id'],axis=1, inplace=True)
patient_lab_and_admission_data.head()
# Out:
#    subject_id  hadm_id  itemid           charttime value  valuenum valueuom  \
# 0         652   100262   50802 2142-04-28 04:15:00   -14    -14.00    mEq/L
# 1         652   100262   50804 2142-04-28 04:15:00    16     16.00    mEq/L
# 2         652   100262   50818 2142-04-28 04:15:00    47     47.00    mm Hg
# 3         652   100262   50820 2142-04-28 04:15:00  7.11      7.11    units
# 4         652   100262   50821 2142-04-28 04:15:00   116    116.00    mm Hg
#
#        flag           admittime admission_type               ethnicity  \
# 0      None 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 1  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 2  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 3  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 4  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
#
#    death_within_30_days gender  age                 label  fluid
# 0                     0      M   21           Base Excess  Blood
# 1                     0      M   21  Calculated Total CO2  Blood
# 2                     0      M   21                  pCO2  Blood
# 3                     0      M   21                    pH  Blood
# 4                     0      M   21                   pO2  Blood

# %% [markdown]
# #### Figure out which vital inormation (or lab events) to use
#
# Note that data is being captured for 409 vital event type (or lab items type). Now, we will analyze this data to figure out which ones to use for machine learning model. We will use the ones that are being consistently captured across all the patients.
#
# ** Here is the logic - ** We have total of 1184 hospital admissions. If a lab item (or vital) data exists for at least 80% of the hospital admission (i.e. 948 hospital admissions), then we are going to use that lab item to build our machine learning model.

# %% [markdown]
# Grouping the data to see how if an items exists for particular hospital admission

# %%
grouped_data = pd.DataFrame(patient_lab_and_admission_data.groupby(['hadm_id','fluid','itemid'])['itemid'].count())
grouped_data.rename(columns={'itemid': 'item_count'}, inplace=True)
grouped_data.reset_index(drop=False, inplace=True)

# %%
grouped_data.head()
# Out:
#    hadm_id  fluid  itemid  item_count
# 0   100262  BLOOD   50800          17
# 1   100262  Blood   50802          16
# 2   100262  Blood   50804          16
# 3   100262  Blood   50808           3
# 4   100262  Blood   50810           1

# %%
grouped_data['item_count'].describe()
# Out:
# count    84853.000000
# mean         2.102695
# std          1.565043
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         25.000000
# Name: item_count, dtype: float64

# %% [markdown]
# If itemid count for a hospital admission is greater than 0, then that item is being flagged as value exists for that hospital admission.

# %%
def to_bool(row):
    if row['item_count'] > 0:
        return 1
    else: 
        return 0
grouped_data['value_exist'] = grouped_data.apply(lambda row: to_bool(row),axis=1)
grouped_data.head()
# Out:
#    hadm_id  fluid  itemid  item_count  value_exist
# 0   100262  BLOOD   50800          17            1
# 1   100262  Blood   50802          16            1
# 2   100262  Blood   50804          16            1
# 3   100262  Blood   50808           3            1
# 4   100262  Blood   50810           1            1

# %% [markdown]
# Creating a pivot table with row as hospital admission and fluid and column as item id

# %%
#grouped_data.pivot(index=['hadm_id','fluid'], columns=['itemid'],values='count')
grouped_data = pd.pivot_table(grouped_data, values = 'value_exist', index=['hadm_id','fluid'], columns = 'itemid').reset_index()

# %%
grouped_data.head()
# Out:
# itemid  hadm_id        fluid  50800  50801  50802  50803  50804  50805  50806  \
# 0        100262        BLOOD      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1        100262        Blood    NaN    NaN      1    NaN      1    NaN    NaN
# 2        100262  Joint Fluid    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3        100262        Urine    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4        100328        Blood    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# itemid  50808  ...    51511  51512  51513  51514  51515  51516  51517  51518  \
# 0         NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1           1  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2         NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3         NaN  ...      NaN    NaN    NaN      1    NaN      1    NaN    NaN
# 4         NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# itemid  51519  51523
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3           1    NaN
# 4         NaN    NaN
#
# [5 rows x 411 columns]

# %% [markdown]
# Filtering out all the lab items (or vitals) that have data for at least 80% of hospital admissions (i.e. 948 hospital admissions)

# %%
filtered_item_ids = grouped_data.sum()
filtered_item_ids = filtered_item_ids[filtered_item_ids > 947]
filtered_item_id_list = filtered_item_ids[2:].index.tolist()

# %%
len(filtered_item_id_list)
# Out:
# 36

# %% [markdown]
# Getting details for filtered out Lab items

# %%
lab_items[lab_items['itemid'].isin(filtered_item_id_list)]
# Out:
#      itemid                            label  fluid
# 12    50813                          Lactate  Blood
# 42    50861   Alanine Aminotransferase (ALT)  Blood
# 44    50863             Alkaline Phosphatase  Blood
# 48    50868                        Anion Gap  Blood
# 54    50878  Asparate Aminotransferase (AST)  Blood
# 57    50882                      Bicarbonate  Blood
# 60    50885                 Bilirubin, Total  Blood
# 67    50893                   Calcium, Total  Blood
# 70    50902                         Chloride  Blood
# 80    50912                       Creatinine  Blood
# 95    50931                          Glucose  Blood
# 121   50960                        Magnesium  Blood
# 129   50970                        Phosphate  Blood
# 130   50971                        Potassium  Blood
# 139   50983                           Sodium  Blood
# 152   51006                    Urea Nitrogen  Blood
# 232   51146                        Basophils  Blood
# 253   51200                      Eosinophils  Blood
# 260   51221                       Hematocrit  Blood
# 261   51222                       Hemoglobin  Blood
# 270   51237                          INR(PT)  Blood
# 275   51244                      Lymphocytes  Blood
# 278   51248                              MCH  Blood
# 279   51249                             MCHC  Blood
# 280   51250                              MCV  Blood
# 283   51254                        Monocytes  Blood
# 285   51256                      Neutrophils  Blood
# 293   51265                   Platelet Count  Blood
# 298   51274                               PT  Blood
# 299   51275                              PTT  Blood
# 300   51277                              RDW  Blood
# 302   51279                  Red Blood Cells  Blood
# 315   51301                White Blood Cells  Blood
# 384   51491                               pH  Urine
# 385   51492                          Protein  Urine
# 388   51498                 Specific Gravity  Urine

# %% [markdown]
# For some lab items, data has been captured but valid values haven't been entered. Value field has comment and valuenum field is null. Analyzing this data to figure out how to do manage such data.

# %%
incomplete_lab_items = patient_lab_and_admission_data[patient_lab_and_admission_data['itemid'].isin(filtered_item_id_list)]
incomplete_lab_items = incomplete_lab_items[['itemid','value','valuenum','flag','label','fluid']]
incomplete_lab_items = incomplete_lab_items[incomplete_lab_items.valuenum.isnull()]['itemid'].value_counts()
incomplete_lab_items
# Out:
# 51492    537
# 51498     25
# 51275      6
# 50882      5
# 50971      4
# 50970      3
# 51301      3
# 51279      3
# 51250      3
# 51248      3
# 51237      3
# 51277      2
# 51222      2
# 50885      2
# 51274      2
# 51249      2
# 50983      1
# 51221      1
# Name: itemid, dtype: int64

# %% [markdown]
# If we remove all the rows with incomplete data, trying to figure out what's the impact it will have on the remaining patient_lab_and_admission_data. Will each of these lab items will still have sufficient entries to train the machine learning model?

# %%
incomplete_lab_items_list = incomplete_lab_items.index.tolist()
filtered_item_ids[filtered_item_ids.index.isin(incomplete_lab_items_list)]
# Out:
# itemid
# 50882    1175
# 50885     998
# 50970    1161
# 50971    1175
# 50983    1175
# 51221    1176
# 51222    1176
# 51237    1118
# 51248    1176
# 51249    1176
# 51250    1176
# 51274    1118
# 51275    1118
# 51277    1176
# 51279    1176
# 51301    1176
# 51492     952
# 51498    1033
# dtype: object

# %% [markdown]
# Now subtracting null or invalid entries from actual number of entries to understand how many rows will be left if we get rid of null/invalid rows.

# %%
filtered_item_ids[filtered_item_ids.index.isin(incomplete_lab_items_list)] - incomplete_lab_items
# Out:
# 50882    1170
# 50885     996
# 50970    1158
# 50971    1171
# 50983    1174
# 51221    1175
# 51222    1174
# 51237    1115
# 51248    1173
# 51249    1174
# 51250    1173
# 51274    1116
# 51275    1112
# 51277    1174
# 51279    1173
# 51301    1173
# 51492     415
# 51498    1008
# dtype: object

# %% [markdown]
# So except for lab item 51492 (Protein/Urine), all other lab items will still have sufficient number of rows on which we can build the machine learning model. So, we will go ahead and drop 51492 from the data.

# %%
filtered_item_id_list.remove(51492)
len(filtered_item_id_list)
# Out:
# 35

# %%
patient_lab_and_admission_data = patient_lab_and_admission_data[patient_lab_and_admission_data['itemid'].isin(filtered_item_id_list)]
patient_lab_and_admission_data.shape
# Out:
# (102898, 16)

# %%
patient_lab_and_admission_data.head()
# Out:
#     subject_id  hadm_id  itemid           charttime value  valuenum valueuom  \
# 12         652   100262   50868 2142-04-28 06:15:00    20      20.0    mEq/L
# 13         652   100262   50882 2142-04-28 06:15:00    13      13.0    mEq/L
# 14         652   100262   50902 2142-04-28 06:15:00   114     114.0    mEq/L
# 17         652   100262   50912 2142-04-28 06:15:00   3.1       3.1    mg/dL
# 18         652   100262   50931 2142-04-28 06:15:00    83      83.0    mg/dL
#
#         flag           admittime admission_type               ethnicity  \
# 12      None 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 13  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 14  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 17  abnormal 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
# 18      None 2142-04-28 04:40:00      EMERGENCY  BLACK/AFRICAN AMERICAN
#
#     death_within_30_days gender  age        label  fluid
# 12                     0      M   21    Anion Gap  Blood
# 13                     0      M   21  Bicarbonate  Blood
# 14                     0      M   21     Chloride  Blood
# 17                     0      M   21   Creatinine  Blood
# 18                     0      M   21      Glucose  Blood

# %% [markdown]
# Now that we have finalized all the lab items that we will use to run machine learning models. I am going to convert the data in a format that can be further analyzed and visualized for machine learning models.

# %%
patient_and_admission_data.shape
# Out:
# (1184, 11)

# %%
patient_lab_and_admission_data['hadm_id'].unique().shape
# Out:
# (1178,)

# %%
discarded_hadm_id = list(set(patient_and_admission_data['hadm_id'].unique().tolist()) - set(patient_lab_and_admission_data['hadm_id'].unique().tolist()))
discarded_hadm_id
# Out:
# [192691, 152550, 187308, 197907, 180378, 169179]

# %%
patient_and_admission_data[patient_and_admission_data['hadm_id'].isin(discarded_hadm_id)]
# Out:
#       subject_id  hadm_id           admittime admission_type insurance  \
# 74          2322   169179 2176-03-14 09:25:00      EMERGENCY  Medicaid
# 384        13355   187308 2157-08-01 14:25:00         URGENT   Private
# 595        25400   197907 2142-05-06 04:33:00      EMERGENCY  Medicare
# 745        30610   180378 2165-05-07 02:27:00         URGENT  Medicare
# 1083       88662   192691 2136-05-01 13:09:00      EMERGENCY  Medicare
# 1177       93800   152550 2153-01-01 13:40:00      EMERGENCY   Private
#
#                    ethnicity  death_within_30_days gender        dob  age  \
# 74    BLACK/AFRICAN AMERICAN                     0      F 2137-09-14   38
# 384                    WHITE                     0      F 2133-05-22   24
# 595                    WHITE                     0      F 2058-06-25   83
# 745    UNKNOWN/NOT SPECIFIED                     0      F 2121-12-11   43
# 1083                   WHITE                     0      M 2066-03-15   70
# 1177                   WHITE                     0      M 2107-08-30   45
#
#        age_bins
# 74     (20, 40]
# 384    (20, 40]
# 595   (80, 100]
# 745    (40, 60]
# 1083   (60, 80]
# 1177   (40, 60]

# %%
x = lab_events[lab_events['itemid'].isin(filtered_item_id_list)]
#x[x['hadm_id'].isin(discarded_hadm_id)]
x[x['hadm_id'].isin([192691])]
# Out:
# Empty DataFrame
# Columns: [row_id, subject_id, hadm_id, itemid, charttime, value, valuenum, valueuom, flag]
# Index: []

# %%
sepsis_festure_list = pd.pivot_table(patient_lab_and_admission_data,values='valuenum',index=['subject_id','hadm_id'],columns='label')
sepsis_festure_list
# Out:
# label               Alanine Aminotransferase (ALT)  Alkaline Phosphatase  \
# subject_id hadm_id
# 21         111970                        47.000000            167.000000
# 94         183686                        90.333333             68.666667
# 157        107880                        13.000000            118.000000
# 166        128219                              NaN                   NaN
# 188        191517                       121.000000            130.000000
# 353        108923                        14.000000             44.000000
#            131488                        13.000000             84.000000
# 357        122609                       104.333333            140.666667
# 366        134462                        68.000000             90.000000
# 406        100765                        16.000000             71.000000
#            113900                        47.500000            178.500000
#            171178                        57.000000            190.000000
# 433        141626                        29.000000            255.000000
# 450        105452                        35.000000            110.000000
# 507        148905                       300.500000             95.500000
# 545        155327                        14.000000             85.000000
# 558        104958                        18.500000             70.000000
# 576        108911                       529.000000            131.000000
# 588        170452                        10.000000             74.000000
# 590        172260                        40.000000            528.000000
# 618        155036                              NaN                   NaN
# 652        100262                        16.500000             84.500000
# 690        133648                         9.000000             79.000000
# 711        114791                              NaN                   NaN
# 781        163526                        31.666667            130.666667
# 914        168503                        66.000000            197.000000
# 940        111612                         7.666667            236.000000
# 945        101713                        35.000000             88.000000
# 1026       103873                         7.000000             97.000000
# 1068       174792                        30.000000            109.000000
# ...                                            ...                   ...
# 95968      114712                        13.333333             61.333333
# 96145      161427                        79.500000             91.500000
# 96240      168044                        58.000000            198.500000
# 96261      150731                        27.500000             89.500000
# 96442      107499                        39.333333            148.000000
# 96553      194204                        17.000000             65.000000
# 96577      108974                       218.000000            233.000000
# 96842      125486                        92.000000             59.500000
# 96962      163165                              NaN                   NaN
# 97039      198499                              NaN                   NaN
# 97042      186645                              NaN                   NaN
# 97143      122472                        21.000000            155.000000
# 97353      125316                              NaN                   NaN
# 97560      128116                        20.000000                   NaN
# 97801      165472                              NaN                   NaN
# 97923      166958                        56.000000             90.000000
# 97924      100380                        26.000000             87.000000
# 98220      132856                        23.000000           1093.000000
# 98384      135001                        53.000000             93.500000
# 98420      123804                        48.500000             89.000000
# 98435      148017                        14.500000             61.000000
# 98554      151063                        23.000000             34.000000
# 98623      107520                       171.000000             60.500000
# 98698      134977                        10.000000             60.666667
# 98744      153703                        35.000000            108.000000
# 98931      185895                              NaN                   NaN
# 99299      166418                              NaN                   NaN
# 99439      177794                              NaN                   NaN
# 99756      172485                        73.000000            241.000000
# 99973      150202                              NaN                   NaN
#
# label               Anion Gap  Asparate Aminotransferase (AST)  Basophils  \
# subject_id hadm_id
# 21         111970   17.000000                        82.000000   0.000000
# 94         183686   14.000000                        82.333333   0.850000
# 157        107880   17.400000                        25.000000   0.000000
# 166        128219   19.000000                              NaN   0.000000
# 188        191517   15.000000                       114.000000   0.000000
# 353        108923   18.666667                        32.000000   0.200000
#            131488   21.750000                        15.000000   0.000000
# 357        122609   13.000000                        96.333333   0.200000
# 366        134462   15.666667                        56.500000   0.000000
# 406        100765   13.500000                        25.000000   0.100000
#            113900   16.666667                        51.000000   0.100000
#            171178   14.000000                        41.500000   0.000000
# 433        141626   22.750000                        41.000000   0.000000
# 450        105452   17.000000                        58.500000   0.300000
# 507        148905   22.333333                       275.500000   0.000000
# 545        155327   16.600000                        54.000000   0.600000
# 558        104958   20.000000                        23.000000   0.650000
# 576        108911   16.500000                       486.000000   0.000000
# 588        170452   18.666667                        21.000000   0.400000
# 590        172260   14.666667                       144.000000   0.000000
# 618        155036   15.500000                              NaN   0.100000
# 652        100262   21.333333                        39.500000   0.000000
# 690        133648   14.666667                        17.000000   0.200000
# 711        114791   15.000000                              NaN   0.300000
# 781        163526   16.600000                        48.666667   0.000000
# 914        168503   15.666667                       155.000000   0.000000
# 940        111612   15.400000                        53.333333   1.000000
# 945        101713   14.000000                        22.000000   0.000000
# 1026       103873   15.000000                        19.000000   0.100000
# 1068       174792   10.500000                        26.000000        NaN
# ...                       ...                              ...        ...
# 95968      114712   16.750000                        24.000000   0.000000
# 96145      161427   14.500000                       101.500000        NaN
# 96240      168044   19.666667                        61.000000   0.000000
# 96261      150731   14.500000                        33.000000   0.200000
# 96442      107499   13.666667                        34.000000   0.000000
# 96553      194204   11.000000                        20.000000   0.100000
# 96577      108974   13.500000                       449.666667   0.133333
# 96842      125486   16.666667                       109.500000   0.100000
# 96962      163165   14.000000                              NaN   0.300000
# 97039      198499   14.500000                              NaN   1.100000
# 97042      186645   14.800000                              NaN   0.500000
# 97143      122472   15.000000                        20.000000   0.100000
# 97353      125316   16.500000                              NaN   0.600000
# 97560      128116   13.833333                        28.000000   0.000000
# 97801      165472   13.500000                              NaN        NaN
# 97923      166958   14.000000                        57.000000   0.300000
# 97924      100380   11.500000                        35.000000   0.300000
# 98220      132856   14.500000                        48.000000   0.000000
# 98384      135001   18.500000                        65.500000   0.000000
# 98420      123804   15.600000                        40.500000   0.650000
# 98435      148017   13.000000                        34.500000   0.200000
# 98554      151063   14.500000                        28.000000   0.000000
# 98623      107520   13.500000                       108.000000   0.100000
# 98698      134977    9.666667                        13.333333   0.000000
# 98744      153703   20.000000                        88.000000   0.000000
# 98931      185895   12.000000                              NaN        NaN
# 99299      166418   16.000000                              NaN   0.500000
# 99439      177794   14.500000                              NaN   1.750000
# 99756      172485   20.666667                       112.000000        NaN
# 99973      150202   13.000000                              NaN   0.133333
#
# label               Bicarbonate  Bilirubin, Total  Calcium, Total    Chloride  \
# subject_id hadm_id
# 21         111970     23.500000          0.300000        7.700000  101.500000
# 94         183686     23.250000          1.033333        8.075000   97.500000
# 157        107880     18.000000          0.600000        7.940000  106.400000
# 166        128219     24.000000               NaN             NaN  103.000000
# 188        191517     17.000000          1.775000        7.725000  107.333333
# 353        108923     28.333333          0.300000        8.766667   97.000000
#            131488     24.500000          0.600000        8.933333   97.500000
# 357        122609     16.400000          0.166667        7.260000  131.800000
# 366        134462     25.000000          0.550000        7.900000  102.333333
# 406        100765     16.000000          0.200000        6.200000  108.500000
#            113900     22.666667          0.800000        7.900000   97.000000
#            171178     16.500000          0.700000        7.025000  111.000000
# 433        141626     20.250000          0.400000        8.766667   99.500000
# 450        105452     20.000000          0.450000        8.400000  119.000000
# 507        148905     14.333333          6.100000        7.850000  107.666667
# 545        155327     18.666667          0.700000        8.300000  107.000000
# 558        104958     21.500000          1.250000        7.950000   99.500000
# 576        108911     18.500000          0.800000        8.100000  112.000000
# 588        170452     24.333333          0.400000        8.733333  104.333333
# 590        172260     17.000000         20.950000        6.750000  112.000000
# 618        155036     18.500000               NaN        8.000000   99.000000
# 652        100262     13.333333          0.550000        6.860000  109.333333
# 690        133648     29.666667          0.400000        8.800000   97.333333
# 711        114791     20.000000               NaN        7.500000  101.000000
# 781        163526     22.400000          1.433333        7.275000  100.200000
# 914        168503     21.666667          1.333333        7.700000  109.000000
# 940        111612     24.800000         14.133333        8.000000  104.800000
# 945        101713     21.666667          0.600000        7.350000  108.333333
# 1026       103873     24.000000          0.300000        8.150000  113.666667
# 1068       174792     24.000000          0.800000        7.000000   97.500000
# ...                         ...               ...             ...         ...
# 95968      114712     15.000000          2.000000        6.900000  101.000000
# 96145      161427     17.500000          0.450000        6.900000  107.500000
# 96240      168044     22.333333          2.500000        6.900000   95.333333
# 96261      150731     16.500000          0.500000        7.925000  106.750000
# 96442      107499     18.666667          0.666667        6.950000  104.333333
# 96553      194204     20.666667          0.400000        7.500000  115.666667
# 96577      108974     23.250000          0.366667        6.533333  102.750000
# 96842      125486     20.666667          0.550000        7.233333  107.333333
# 96962      163165     21.000000               NaN        7.050000  110.750000
# 97039      198499     23.500000               NaN        7.700000  130.166667
# 97042      186645     23.000000               NaN        7.800000  118.200000
# 97143      122472     19.500000          0.400000        8.100000  108.500000
# 97353      125316     26.000000               NaN        7.300000   94.500000
# 97560      128116     17.000000          0.600000        7.400000  130.166667
# 97801      165472     17.000000               NaN        7.350000  106.500000
# 97923      166958     20.500000          0.500000        7.700000  106.500000
# 97924      100380     22.500000          0.900000        7.900000  106.000000
# 98220      132856     20.500000          3.700000        8.250000  108.500000
# 98384      135001     15.500000          1.300000        7.250000  108.500000
# 98420      123804     14.200000          0.600000        8.225000  127.200000
# 98435      148017     19.333333          0.450000        6.433333  103.000000
# 98554      151063     16.500000          0.500000        7.500000  109.500000
# 98623      107520     25.000000          0.400000        8.150000  103.000000
# 98698      134977     20.000000          0.433333        7.333333  109.666667
# 98744      153703     17.666667          2.100000        7.666667  106.333333
# 98931      185895     26.500000               NaN        8.200000  100.000000
# 99299      166418     20.500000               NaN        9.000000  118.000000
# 99439      177794     35.500000               NaN        8.650000  111.142857
# 99756      172485     19.000000          5.300000        8.966667   99.333333
# 99973      150202     13.000000               NaN        7.400000  117.000000
#
# label               Creatinine  ...   Phosphate  Platelet Count  Potassium  \
# subject_id hadm_id              ...
# 21         111970     4.200000  ...    4.400000      353.500000   3.600000
# 94         183686     0.700000  ...    2.700000      155.666667   3.100000
# 157        107880     0.575000  ...    4.250000      247.600000   4.180000
# 166        128219     0.800000  ...         NaN      341.000000   3.700000
# 188        191517     1.725000  ...    3.300000      249.000000   5.066667
# 353        108923     7.000000  ...    3.200000      152.500000   5.325000
#            131488     6.375000  ...    3.000000      117.000000   4.850000
# 357        122609     1.220000  ...    2.050000       82.750000   3.260000
# 366        134462     1.466667  ...    2.100000      199.000000   4.500000
# 406        100765     1.300000  ...    2.300000      152.000000   5.100000
#            113900     1.366667  ...    2.550000      228.333333   3.275000
#            171178     1.200000  ...    2.275000      137.000000   3.425000
# 433        141626     5.475000  ...    4.966667      180.750000   4.625000
# 450        105452     0.975000  ...    2.800000      401.000000   4.175000
# 507        148905     1.300000  ...    4.100000       96.750000   3.833333
# 545        155327     1.966667  ...    5.400000      242.166667   4.920000
# 558        104958     1.100000  ...    2.150000      226.000000   3.750000
# 576        108911     2.100000  ...    3.950000       70.000000   4.400000
# 588        170452     4.566667  ...    3.866667      318.666667   3.800000
# 590        172260     0.900000  ...    1.825000      252.500000   3.375000
# 618        155036     0.850000  ...    2.300000      232.000000   3.600000
# 652        100262     3.866667  ...    3.280000       58.428571   4.566667
# 690        133648     2.750000  ...    3.900000      251.000000   4.133333
# 711        114791     0.800000  ...    3.100000      453.333333   3.266667
# 781        163526     1.360000  ...    3.825000      325.800000   5.220000
# 914        168503     0.800000  ...    2.100000      103.000000   3.500000
# 940        111612     1.940000  ...    3.933333      283.400000   3.440000
# 945        101713     0.566667  ...    3.000000      138.000000   3.700000
# 1026       103873     1.333333  ...    3.600000      211.500000   4.900000
# 1068       174792     0.200000  ...    3.000000       74.000000   3.800000
# ...                        ...  ...         ...             ...        ...
# 95968      114712     1.675000  ...    2.825000      139.666667   3.600000
# 96145      161427     0.650000  ...    2.200000      146.500000   3.500000
# 96240      168044     1.566667  ...    4.050000      469.500000   3.700000
# 96261      150731     2.175000  ...    3.100000      283.333333   5.650000
# 96442      107499     1.533333  ...    3.600000      320.666667   3.566667
# 96553      194204     0.933333  ...    1.350000       87.000000   3.466667
# 96577      108974     0.450000  ...    3.300000      148.666667   3.975000
# 96842      125486     3.366667  ...    5.000000       66.666667   4.533333
# 96962      163165     0.975000  ...    3.700000      530.000000   4.250000
# 97039      198499     1.900000  ...    1.900000      221.500000   3.600000
# 97042      186645     0.600000  ...    3.233333      254.500000   4.260000
# 97143      122472     1.400000  ...    3.233333      284.333333   3.750000
# 97353      125316     9.000000  ...    3.950000      152.666667   3.900000
# 97560      128116     1.485714  ...    5.550000       60.666667   4.000000
# 97801      165472     1.133333  ...    4.250000      182.666667   3.950000
# 97923      166958     0.650000  ...    2.400000      230.500000   3.750000
# 97924      100380     0.800000  ...    3.000000      193.666667   3.600000
# 98220      132856     0.750000  ...    2.200000      505.500000   4.150000
# 98384      135001     2.900000  ...    4.450000      157.250000   4.300000
# 98420      123804     1.280000  ...    3.000000      325.250000   3.460000
# 98435      148017     1.300000  ...    2.466667      173.666667   3.433333
# 98554      151063     0.850000  ...    2.700000      182.000000   4.400000
# 98623      107520     0.700000  ...    3.050000      129.666667   4.050000
# 98698      134977     1.000000  ...    2.300000      533.333333   4.425000
# 98744      153703     3.400000  ...    3.533333      198.500000   5.000000
# 98931      185895     1.150000  ...    2.800000      164.500000   3.900000
# 99299      166418     2.350000  ...    1.500000      133.500000   3.900000
# 99439      177794     3.483333  ...    5.550000      102.500000   3.742857
# 99756      172485     3.366667  ...    6.966667       35.666667   4.266667
# 99973      150202     1.433333  ...    4.300000      311.333333   3.500000
#
# label                     RDW  Red Blood Cells      Sodium  Specific Gravity  \
# subject_id hadm_id
# 21         111970   17.300000         3.075000  138.500000               NaN
# 94         183686   13.733333         3.966667  131.500000            1.0090
# 157        107880   18.960000         2.952000  137.600000            1.0170
# 166        128219   13.900000         3.980000  142.000000            1.0200
# 188        191517   16.075000         3.637500  134.000000            1.0210
# 353        108923   16.150000         3.050000  139.000000            1.0140
#            131488   16.000000         3.500000  139.000000            1.0110
# 357        122609   15.250000         2.477500  157.000000            1.0245
# 366        134462   16.350000         4.000000  138.666667            1.0155
# 406        100765   13.200000         2.850000  133.000000            1.0110
#            113900   14.033333         2.976667  133.000000            1.0110
#            171178   14.300000         3.485000  138.000000            1.0180
# 433        141626   18.025000         3.902500  137.750000               NaN
# 450        105452   17.050000         5.050000  149.500000            1.0260
# 507        148905   14.833333         3.777500  140.333333            1.0150
# 545        155327   17.250000         3.328333  137.333333            1.0110
# 558        104958   13.550000         4.565000  137.000000            1.0200
# 576        108911   15.500000         4.310000  142.500000            1.0180
# 588        170452   18.100000         3.273333  143.666667            1.0150
# 590        172260   21.350000         3.180000  140.333333            1.0210
# 618        155036   16.766667         3.520000  130.333333            1.0150
# 652        100262   13.957143         4.335714  139.500000            1.0230
# 690        133648   15.750000         4.010000  137.333333            1.0150
# 711        114791   14.500000         3.330000  133.000000            1.0270
# 781        163526   15.400000         3.560000  134.000000            1.0150
# 914        168503   16.633333         3.216667  142.666667            1.0090
# 940        111612   22.760000         3.398000  141.400000            1.0105
# 945        101713   13.866667         3.726667  140.333333            1.0230
# 1026       103873   17.750000         3.585000  147.666667            1.0100
# 1068       174792   14.350000         3.380000  128.000000            1.0190
# ...                       ...              ...         ...               ...
# 95968      114712   15.466667         2.653333  129.250000            1.0150
# 96145      161427   13.300000         3.280000  136.000000            1.0120
# 96240      168044   15.750000         2.775000  133.666667            1.0245
# 96261      150731   24.766667         4.536667  132.250000            1.0200
# 96442      107499   16.766667         3.376667  132.666667            1.0205
# 96553      194204   15.300000         3.280000  144.000000            1.0080
# 96577      108974   14.166667         4.176667  135.500000            1.0190
# 96842      125486   14.333333         3.163333  140.000000               NaN
# 96962      163165   15.525000         2.832500  141.500000            1.0100
# 97039      198499   15.900000         3.585000  162.333333            1.0200
# 97042      186645   17.350000         3.935000  151.800000            1.0300
# 97143      122472   16.266667         2.476667  139.500000            1.0170
# 97353      125316   15.866667         2.706667  133.000000            1.0170
# 97560      128116   21.066667         3.735000  157.000000            1.0170
# 97801      165472   17.066667         4.420000  133.000000            1.0500
# 97923      166958   14.200000         3.480000  137.000000            1.0080
# 97924      100380   14.233333         3.513333  136.000000               NaN
# 98220      132856   17.700000         3.035000  139.500000            1.0320
# 98384      135001   17.850000         3.227500  138.500000            1.0160
# 98420      123804   14.425000         3.372500  153.400000            1.0110
# 98435      148017   15.400000         2.780000  131.666667            1.0190
# 98554      151063   16.033333         3.633333  136.000000            1.0125
# 98623      107520   13.466667         3.576667  137.000000            1.0170
# 98698      134977   15.933333         4.063333  135.000000            1.0360
# 98744      153703   17.400000         4.085000  139.333333            1.0120
# 98931      185895   13.350000         4.665000  134.500000            1.0250
# 99299      166418   13.200000         3.835000  150.500000            1.0200
# 99439      177794   16.900000         5.960000  156.714286            1.0090
# 99756      172485   17.000000         1.973333  135.000000               NaN
# 99973      150202   15.266667         3.260000  139.666667            1.0050
#
# label               Urea Nitrogen  White Blood Cells    pH
# subject_id hadm_id
# 21         111970       49.500000          35.850000   NaN
# 94         183686        8.666667           6.066667  8.00
# 157        107880       12.250000          59.300000  6.50
# 166        128219       20.000000          16.500000  6.00
# 188        191517       28.250000          19.275000  6.00
# 353        108923       63.500000          11.250000  8.00
#            131488       47.000000           7.933333  9.00
# 357        122609       56.200000           3.550000  5.00
# 366        134462       16.000000          27.900000  6.25
# 406        100765       17.000000           7.050000  5.00
#            113900       23.333333          14.066667  7.00
#            171178       19.500000          12.050000  6.50
# 433        141626       33.250000           8.000000   NaN
# 450        105452       30.000000          15.150000  5.00
# 507        148905       30.666667          19.350000  5.00
# 545        155327       53.166667           3.900000  5.00
# 558        104958       15.500000           7.050000  5.00
# 576        108911       53.000000          46.200000  5.00
# 588        170452       33.000000          19.500000  7.00
# 590        172260       15.333333          16.350000  7.50
# 618        155036       15.000000          16.833333  6.00
# 652        100262       27.833333          19.842857  5.00
# 690        133648       19.500000          15.000000  9.00
# 711        114791       31.500000          12.333333  6.50
# 781        163526       42.400000          10.290000  5.50
# 914        168503       11.333333           4.966667  5.00
# 940        111612       53.000000           2.560000  5.75
# 945        101713       10.666667           0.400000  5.00
# 1026       103873       40.666667          24.850000  9.00
# 1068       174792       15.000000           0.250000  7.00
# ...                           ...                ...   ...
# 95968      114712       22.750000           5.200000  5.00
# 96145      161427        8.500000          13.600000  6.00
# 96240      168044       37.000000          41.000000  5.25
# 96261      150731       33.000000          18.466667  5.00
# 96442      107499       18.000000          16.700000  5.75
# 96553      194204        8.333333           7.650000  6.50
# 96577      108974        4.500000          16.500000  6.25
# 96842      125486       66.000000          13.966667   NaN
# 96962      163165       11.750000          17.750000  6.00
# 97039      198499       35.833333           9.550000  5.00
# 97042      186645       25.200000           9.350000  5.00
# 97143      122472       56.000000          14.366667  5.00
# 97353      125316       74.000000          11.466667  5.00
# 97560      128116       72.857143           8.383333  5.00
# 97801      165472       32.666667          12.066667  6.50
# 97923      166958       12.000000           5.450000  5.00
# 97924      100380       20.000000          13.766667  6.00
# 98220      132856       36.500000          24.950000  6.50
# 98384      135001       85.000000          11.925000  5.00
# 98420      123804       75.400000          17.875000  5.00
# 98435      148017       46.000000          13.133333  5.00
# 98554      151063       18.500000          12.466667  5.50
# 98623      107520       13.500000           4.175000  5.50
# 98698      134977        9.750000          19.933333  5.00
# 98744      153703       62.333333          19.100000  6.00
# 98931      185895       18.500000           9.200000  5.00
# 99299      166418       46.000000           8.450000  5.00
# 99439      177794       62.166667          10.650000  5.50
# 99756      172485       50.000000           4.266667   NaN
# 99973      150202       19.333333          17.200000  5.00
#
# [1178 rows x 35 columns]

# %%
sepsis_festure_list.shape
# Out:
# (1178, 35)

# %% [markdown]
# ## Retreive and Analyze patients infection data within 24 hours of admission
#
# Goal here is to figure out which dataset to use to build machine learning model. I considered multiple options -
#
# 1. Number of infections a patient has
#
# 2. Infection by Specimen type (e.g. Sputum infection, Blood infection etc.)
#
# 3. Organism that's present in patient's body
#
# For this particular project, I went with option #1 and #2. There is enough data available for this and my guess is that this should provide a good prediction.
#
# As can be seen below - for option# 3, there is not enough data available at each organism level to use for machine learning modelling.

# %% [markdown]
# ##### Filtering out all the data for patients diagnosed with Sepsis

# %%
patient_hadm_ids = patient_and_admission_data.hadm_id.tolist()

bioevent_query = session.query(BioEvent).filter(BioEvent.hadm_id.in_(patient_hadm_ids))

patient_bio_event = pd.read_sql(bioevent_query.statement, bioevent_query.session.bind)

# %%
patient_bio_event.head()
# Out:
#    row_id  subject_id  hadm_id  chartdate           charttime  spec_itemid  \
# 0    8257         652   100262 2142-06-05 2142-06-05 17:12:00        70062
# 1    8258         652   100262 2142-06-05 2142-06-05 17:12:00        70062
# 2    8259         652   100262 2142-06-05 2142-06-05 17:12:00        70062
# 3    8260         652   100262 2142-06-05 2142-06-05 17:12:00        70062
# 4    8261         652   100262 2142-06-05 2142-06-05 17:12:00        70062
#
#   spec_type_desc  org_itemid                                   org_name  \
# 0         SPUTUM       80225  NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA
# 1         SPUTUM       80225  NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA
# 2         SPUTUM       80225  NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA
# 3         SPUTUM       80225  NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA
# 4         SPUTUM       80225  NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA
#
#    isolate_num  ab_itemid      ab_name dilution_text dilution_comparison  \
# 0            1      90013   TOBRAMYCIN           =>8                  =>
# 1            1      90028     CEFEPIME            16                   =
# 2            1      90018  CEFTRIAXONE          =>32                  =>
# 3            1      90029    MEROPENEM             1                   =
# 4            1      90017  CEFTAZIDIME            16                   =
#
#    dilution_value interpretation
# 0               8              R
# 1              16              R
# 2              32              R
# 3               1              S
# 4              16              I

# %% [markdown]
# #### Org_name vs. Org_itemid?
#
# In order to figure out, if a patient has particular infection or not. Should we use Org_id or Org_name?
#
# Based upon analysis below, it appears that org_name has 67 more data points. So, I will use org_name to figure out if patient has infection.

# %%
patient_bio_event.org_name.isnull().sum()
# Out:
# 11495

# %%
patient_bio_event.org_itemid.isnull().sum()
# Out:
# 11562

# %%
patient_bio_event[patient_bio_event.org_name.notnull() & patient_bio_event.org_itemid.isnull()].shape
# Out:
# (67, 16)

# %% [markdown]
# #### Remove columns and join with patients admissions data to get admission time

# %%
patient_bio_event.shape
# Out:
# (29281, 8)

# %%
patient_bio_event.columns
# Out:
# Index([u'row_id', u'subject_id', u'hadm_id', u'chartdate', u'charttime',
#        u'spec_itemid', u'spec_type_desc', u'org_itemid', u'org_name',
#        u'isolate_num', u'ab_itemid', u'ab_name', u'dilution_text',
#        u'dilution_comparison', u'dilution_value', u'interpretation'],
#       dtype='object')

# %%
columns_to_keep = ['subject_id','hadm_id','charttime','spec_type_desc','org_name']
patient_bio_event = patient_bio_event[columns_to_keep]

# %%
patient_bio_event = patient_bio_event.merge(patient_and_admission_data[['subject_id','hadm_id','admittime','death_within_30_days','age']],on=['subject_id','hadm_id'],how='left')

# %%
patient_bio_event.shape
# Out:
# (29281, 8)

# %% [markdown]
# #### Filtering out all the infections that were reported within 24 hours of Admission or 48 hours prior to admission
#
# Picking up data 48 hours prior as many times admit time is recorded late or admission happens after all the testing.

# %%
patient_bio_event = patient_bio_event[(patient_bio_event['charttime'] - patient_bio_event['admittime'] < pd.Timedelta('1 days'))]
patient_bio_event = patient_bio_event[(patient_bio_event['charttime'] - patient_bio_event['admittime'] > pd.Timedelta('-2 days'))]
patient_bio_event.reset_index(inplace=True)
patient_bio_event.shape
# Out:
# (13284, 9)

# %% [markdown]
# #### Evaluate number of infections as feature (option# 1)

# %%
patient_bio_event.subject_id.unique().shape
# Out:
# (1066,)

# %%
patient_bio_event.hadm_id.unique().shape
# Out:
# (1152,)

# %%
num_of_infection_per_patient = patient_bio_event[patient_bio_event['org_name'].notnull()]
num_of_infection_per_patient = num_of_infection_per_patient[['subject_id','hadm_id','spec_type_desc','org_name']]
num_of_infection_per_patient.shape
# Out:
# (9458, 4)

# %%
num_of_infection_per_patient = num_of_infection_per_patient.drop_duplicates()
num_of_infection_per_patient.shape
# Out:
# (1449, 4)

# %%
num_of_infection_per_patient.head()
# Out:
#     subject_id  hadm_id          spec_type_desc  \
# 6          652   100262  BRONCHOALVEOLAR LAVAGE
# 11       56149   100350             MRSA SCREEN
# 24        7478   100539           BLOOD CULTURE
# 27        7478   100539                  SPUTUM
# 42       23535   100598                   STOOL
#
#                                            org_name
# 6                                             YEAST
# 11  POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS
# 24                            KLEBSIELLA PNEUMONIAE
# 27                            KLEBSIELLA PNEUMONIAE
# 42                            CLOSTRIDIUM DIFFICILE

# %%
num_of_infection_per_patient = num_of_infection_per_patient.groupby(['subject_id','hadm_id'])['spec_type_desc','org_name'].size().reset_index(name="num_of_infections")

# %%
num_of_infection_per_patient.head(10)
# Out:
#    subject_id  hadm_id  num_of_infections
# 0          21   111970                  2
# 1         157   107880                  3
# 2         166   128219                  1
# 3         353   108923                  3
# 4         353   131488                  1
# 5         406   113900                  2
# 6         406   171178                  5
# 7         507   148905                  2
# 8         576   108911                  2
# 9         588   170452                  6

# %% [markdown]
# #### *Outcome of evaluation of option 1*
#
# We have data for num_of_infections for enough customers, so we are going to use this option as feature.

# %% [markdown]
# #### Evaluate specimen type available in the data as feature (option# 2)
#
# Based upon the data below, 42 specimens types are available. Also these data are available for a majority of customers (i.e. 1152 customers).

# %%
patient_bio_event.spec_type_desc.unique().shape
# Out:
# (42,)

# %%
patient_bio_event.hadm_id.unique().shape
# Out:
# (1152,)

# %%
patient_bio_event['spec_type_desc'].value_counts()
# Out:
# BLOOD CULTURE                                               5604
# URINE                                                       3320
# SPUTUM                                                      1357
# SWAB                                                         968
# MRSA SCREEN                                                  412
# STOOL                                                        318
# CATHETER TIP-IV                                              260
# TISSUE                                                       144
# BILE                                                         118
# PERITONEAL FLUID                                             112
# FLUID,OTHER                                                   81
# JOINT FLUID                                                   59
# BLOOD CULTURE ( MYCO/F LYTIC BOTTLE)                          58
# FLUID RECEIVED IN BLOOD CULTURE BOTTLES                       49
# PLEURAL FLUID                                                 46
# CSF;SPINAL FLUID                                              39
# BRONCHOALVEOLAR LAVAGE                                        35
# ABSCESS                                                       35
# Influenza A/B by DFA                                          34
# Rapid Respiratory Viral Screen & Culture                      33
# SEROLOGY/BLOOD                                                26
# Mini-BAL                                                      22
# FOOT CULTURE                                                  21
# FOREIGN BODY                                                  20
# URINE,KIDNEY                                                  18
# Immunology (CMV)                                              14
# ASPIRATE                                                      12
# BRONCHIAL WASHINGS                                            11
# Blood (EBV)                                                   10
# IMMUNOLOGY                                                     9
# Blood (CMV AB)                                                 8
# DIALYSIS FLUID                                                 7
# POSTMORTEM CULTURE                                             5
# THROAT FOR STREP                                               4
# Direct Antigen Test for Herpes Simplex Virus Types 1 & 2       3
# EYE                                                            3
# Blood (Toxo)                                                   2
# THROAT CULTURE                                                 2
# URINE,SUPRAPUBIC ASPIRATE                                      2
# Influenza A/B by DFA - Bronch Wash                             1
# DIRECT ANTIGEN TEST FOR VARICELLA-ZOSTER VIRUS                 1
# BONE MARROW - CYTOGENETICS                                     1
# Name: spec_type_desc, dtype: int64

# %%
grouped_data = pd.DataFrame(patient_bio_event.groupby(['subject_id', 'hadm_id','spec_type_desc'])['spec_type_desc'].count())
grouped_data.rename(columns={'spec_type_desc': 'spec_type_count'}, inplace=True)
grouped_data.reset_index(drop=False,inplace=True)
grouped_data.head()
# Out:
#    subject_id  hadm_id   spec_type_desc  spec_type_count
# 0          21   111970    BLOOD CULTURE                8
# 1          21   111970  CATHETER TIP-IV                1
# 2          21   111970            STOOL                1
# 3          21   111970            URINE                2
# 4          94   183686    BLOOD CULTURE                2

# %% [markdown]
# Note for a patient in single admission, there are multiple entries for same specimen type. A unique entry is being created for each specimen type.

# %%
def to_bool(row):
    if row['spec_type_count'] > 0:
        return 1
    else: 
        return 0
    
grouped_data['value_exist'] = grouped_data.apply(lambda row: to_bool(row),axis=1)
grouped_data.head()
# Out:
#    subject_id  hadm_id   spec_type_desc  spec_type_count  value_exist
# 0          21   111970    BLOOD CULTURE                8            1
# 1          21   111970  CATHETER TIP-IV                1            1
# 2          21   111970            STOOL                1            1
# 3          21   111970            URINE                2            1
# 4          94   183686    BLOOD CULTURE                2            1

# %%
freq_of_specimentype_across_admissions = grouped_data.groupby(['spec_type_desc'])['value_exist'].sum()
freq_of_specimentype_across_admissions.sort(ascending=False)
freq_of_specimentype_across_admissions
# Out:
# spec_type_desc
# BLOOD CULTURE                                               1080
# URINE                                                        809
# MRSA SCREEN                                                  362
# SPUTUM                                                       267
# STOOL                                                        261
# SWAB                                                         116
# CATHETER TIP-IV                                               94
# BLOOD CULTURE ( MYCO/F LYTIC BOTTLE)                          52
# CSF;SPINAL FLUID                                              34
# Influenza A/B by DFA                                          33
# Rapid Respiratory Viral Screen & Culture                      30
# PERITONEAL FLUID                                              28
# SEROLOGY/BLOOD                                                25
# TISSUE                                                        15
# Immunology (CMV)                                              14
# BILE                                                          14
# BRONCHOALVEOLAR LAVAGE                                        14
# FLUID RECEIVED IN BLOOD CULTURE BOTTLES                       14
# ASPIRATE                                                      12
# JOINT FLUID                                                   11
# Blood (EBV)                                                   10
# IMMUNOLOGY                                                     8
# Blood (CMV AB)                                                 8
# PLEURAL FLUID                                                  8
# FLUID,OTHER                                                    7
# DIALYSIS FLUID                                                 7
# ABSCESS                                                        7
# FOOT CULTURE                                                   5
# BRONCHIAL WASHINGS                                             5
# THROAT FOR STREP                                               4
# Mini-BAL                                                       4
# FOREIGN BODY                                                   3
# Direct Antigen Test for Herpes Simplex Virus Types 1 & 2       3
# Blood (Toxo)                                                   2
# EYE                                                            2
# URINE,KIDNEY                                                   2
# THROAT CULTURE                                                 2
# DIRECT ANTIGEN TEST FOR VARICELLA-ZOSTER VIRUS                 1
# BONE MARROW - CYTOGENETICS                                     1
# Influenza A/B by DFA - Bronch Wash                             1
# POSTMORTEM CULTURE                                             1
# URINE,SUPRAPUBIC ASPIRATE                                      1
# Name: value_exist, dtype: int64

# %% [markdown]
# *With specimen types, there are 5 specimens that have more than 10% data. We will use those specimens as features. Those specimens will be Blood Culture, Urine, MRSA SCREEN, SPUTUM STOOL and SWAB.*

# %% [markdown]
# Based upon option# 2, organizing the features by subject id and hospital admission id to use with machine learning model.

# %%
infection_by_specimen_type = patient_bio_event[patient_bio_event['spec_type_desc'].isin(['BLOOD CULTURE','URINE','MRSA SCREEN','SPUTUM','STOOL','SWAB'])]
infection_by_specimen_type = infection_by_specimen_type[['subject_id','hadm_id','spec_type_desc','org_name']]
infection_by_specimen_type.head()
# Out:
#    subject_id  hadm_id spec_type_desc org_name
# 0         652   100262          STOOL     None
# 1         652   100262  BLOOD CULTURE     None
# 2         652   100262  BLOOD CULTURE     None
# 3         652   100262          URINE     None
# 5         652   100262         SPUTUM     None

# %%
infection_by_specimen_type = infection_by_specimen_type.drop_duplicates()
infection_by_specimen_type.head()
# Out:
#    subject_id  hadm_id spec_type_desc org_name
# 0         652   100262          STOOL     None
# 1         652   100262  BLOOD CULTURE     None
# 3         652   100262          URINE     None
# 5         652   100262         SPUTUM     None
# 8       30460   100328          URINE     None

# %%
infection_by_specimen_type=infection_by_specimen_type[infection_by_specimen_type['org_name'].notnull()]
infection_by_specimen_type.head()
# Out:
#     subject_id  hadm_id spec_type_desc  \
# 11       56149   100350    MRSA SCREEN
# 24        7478   100539  BLOOD CULTURE
# 27        7478   100539         SPUTUM
# 42       23535   100598          STOOL
# 43       23535   100598          URINE
#
#                                            org_name
# 11  POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS
# 24                            KLEBSIELLA PNEUMONIAE
# 27                            KLEBSIELLA PNEUMONIAE
# 42                            CLOSTRIDIUM DIFFICILE
# 43                            KLEBSIELLA PNEUMONIAE

# %%
infection_by_specimen_type_per_admission = pd.pivot_table(infection_by_specimen_type, index=['subject_id','hadm_id'], columns='spec_type_desc', values='org_name', aggfunc=len, fill_value=0)
infection_by_specimen_type_per_admission.reset_index(inplace=True)
infection_by_specimen_type_per_admission.shape
# Out:
# (663, 8)

# %% [markdown]
# #### Evaluate Organism as feature (discussed as option# 3 above)
#
# Let's first see if we can use organism name as feature

# %%
patient_bio_event['org_name'].value_counts()
# Out:
# ESCHERICHIA COLI                                          2604
# STAPH AUREUS COAG +                                       1931
# KLEBSIELLA PNEUMONIAE                                      885
# PROTEUS MIRABILIS                                          843
# PSEUDOMONAS AERUGINOSA                                     676
# STAPHYLOCOCCUS, COAGULASE NEGATIVE                         559
# ENTEROCOCCUS SP.                                           252
# YEAST                                                      138
# KLEBSIELLA OXYTOCA                                         129
# SERRATIA MARCESCENS                                        108
# STREPTOCOCCUS PNEUMONIAE                                    97
# ENTEROBACTER CLOACAE                                        88
# GRAM NEGATIVE ROD(S)                                        75
# CITROBACTER FREUNDII COMPLEX                                70
# ENTEROCOCCUS FAECIUM                                        59
# POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS             58
# ENTEROCOCCUS FAECALIS                                       57
# PROVIDENCIA STUARTII                                        44
# CLOSTRIDIUM DIFFICILE                                       42
# CITROBACTER KOSERI                                          42
# BETA STREPTOCOCCUS GROUP A                                  41
# CORYNEBACTERIUM SPECIES (DIPHTHEROIDS)                      37
# NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA                   35
# STREPTOCOCCUS ANGINOSUS (MILLERI) GROUP                     31
# BETA STREPTOCOCCUS GROUP B                                  28
# ENTEROBACTER CLOACAE COMPLEX                                27
# BACTEROIDES FRAGILIS GROUP                                  27
# LACTOBACILLUS SPECIES                                       26
# VIRIDANS STREPTOCOCCI                                       26
# MORGANELLA MORGANII                                         26
#                                                           ...
# PENICILLIUM SPECIES                                          3
# BETA STREPTOCOCCUS GROUP G                                   3
# PRESUMPTIVE VEILLONELLA SPECIES                              3
# PRESUMPTIVE CLOSTRIDIUM SEPTICUM                             3
# PRESUMPTIVE STREPTOCOCCUS BOVIS                              2
# INFLUENZA A VIRUS                                            2
# AFB GROWN IN CULTURE; ADDITIONAL INFORMATION TO FOLLOW       2
# FUNGUS                                                       2
# HAEMOPHILUS INFLUENZAE, BETA-LACTAMASE NEGATIVE              2
# STAPHYLOCOCCUS SPECIES                                       2
# PROBABLE MICROCOCCUS SPECIES                                 1
# PROBABLE GARDNERELLA VAGINALIS                               1
# HERPES SIMPLEX VIRUS TYPE 2                                  1
# POSITIVE FOR INFLUENZA A VIRAL ANTIGEN                       1
# CLOSTRIDIUM PERFRINGENS                                      1
# ANAEROBIC GRAM NEGATIVE ROD #2                               1
# STRONGYLOIDES STERCORALIS                                    1
# POSITIVE FOR ADENOVIRUS                                      1
# RHINOVIRUS                                                   1
# NO GROWTH                                                    1
# GRAM NEGATIVE ROD #4                                         1
# CYTOMEGALOVIRUS                                              1
# CANDIDA TROPICALIS                                           1
# ORGANISM                                                     1
# VARICELLA-ZOSTER VIRUS                                       1
# AEROCOCCUS VIRIDANS                                          1
# MOLD                                                         1
# MODERATE BLASTOCYSTIS HOMINIS                                1
# MORAXELLA CATARRHALIS                                        1
# PRESUMPTIVE GARDNERELLA VAGINALIS                            1
# Name: org_name, dtype: int64

# %%
grouped_data = pd.DataFrame(patient_bio_event.groupby(['hadm_id','org_name'])['org_name'].count())
grouped_data.rename(columns={'org_name': 'org_name_count'}, inplace=True)
grouped_data.reset_index(drop=False,inplace=True)
grouped_data.head()
# Out:
#    hadm_id                                         org_name  org_name_count
# 0   100262                                            YEAST               1
# 1   100350  POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS               1
# 2   100539                            KLEBSIELLA PNEUMONIAE              16
# 3   100598                            CLOSTRIDIUM DIFFICILE               1
# 4   100598                            KLEBSIELLA PNEUMONIAE              14

# %% [markdown]
# Turns out there are duplicate rows for each test against hospital admission id. This is because this table also stores antibiotics information. Multiple antibiotics can be used for a single specimen type. Creating a single number for each duplicate entries.

# %%
def to_bool(row):
    if row['org_name_count'] > 0:
        return 1
    else: 
        return 0
grouped_data['value_exist'] = grouped_data.apply(lambda row: to_bool(row),axis=1)
grouped_data.head()
# Out:
#    hadm_id                                         org_name  org_name_count  \
# 0   100262                                            YEAST               1
# 1   100350  POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS               1
# 2   100539                            KLEBSIELLA PNEUMONIAE              16
# 3   100598                            CLOSTRIDIUM DIFFICILE               1
# 4   100598                            KLEBSIELLA PNEUMONIAE              14
#
#    value_exist
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
freq_of_organism_across_admissions = grouped_data.groupby(['org_name'])['value_exist'].sum()
freq_of_organism_across_admissions.sort(ascending=False)
freq_of_organism_across_admissions.head(10)
# Out:
# org_name
# STAPH AUREUS COAG +                                172
# ESCHERICHIA COLI                                   134
# YEAST                                              118
# STAPHYLOCOCCUS, COAGULASE NEGATIVE                  93
# PSEUDOMONAS AERUGINOSA                              65
# GRAM NEGATIVE ROD(S)                                64
# ENTEROCOCCUS SP.                                    56
# PROTEUS MIRABILIS                                   51
# KLEBSIELLA PNEUMONIAE                               50
# POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS     42
# Name: value_exist, dtype: int64

# %% [markdown]
# #### *Outcome of evaluation of option# 3*
#
# *As can be seen above, not a single organism has data for more than 20% of ICU admissions. So for now, we will ignore option# 3 and will not use organism name as feature.*

# %%
# %who_ls DataFrame
# Out:
# ['X',
#  'admissions',
#  'df',
#  'grouped_data',
#  'infection_by_specimen_type',
#  'infection_by_specimen_type_per_admission',
#  'lab_events',
#  'lab_items',
#  'merged_table',
#  'num_of_infection_per_patient',
#  'patient_and_admission_data',
#  'patient_bio_event',
#  'patient_lab_and_admission_data',
#  'patients',
#  'percent_death_within_30_days_by_agegroup',
#  'percent_death_within_30_days_by_ethnicity',
#  'percent_death_within_30_days_by_gender',
#  'percent_death_within_30_days_by_insurance',
#  'sepsis_festure_list',
#  'test',
#  'x']

# %% [markdown]
# ### Merging demographics, vital and infection data to build a single feature list

# %%
sepsis_festure_list.reset_index(inplace=True)
sepsis_festure_list.head()
# Out:
# label  subject_id  hadm_id  Alanine Aminotransferase (ALT)  \
# 0              21   111970                       47.000000
# 1              94   183686                       90.333333
# 2             157   107880                       13.000000
# 3             166   128219                             NaN
# 4             188   191517                      121.000000
#
# label  Alkaline Phosphatase  Anion Gap  Asparate Aminotransferase (AST)  \
# 0                167.000000       17.0                        82.000000
# 1                 68.666667       14.0                        82.333333
# 2                118.000000       17.4                        25.000000
# 3                       NaN       19.0                              NaN
# 4                130.000000       15.0                       114.000000
#
# label  Basophils  Bicarbonate  Bilirubin, Total  Calcium, Total ...   \
# 0           0.00        23.50          0.300000           7.700 ...
# 1           0.85        23.25          1.033333           8.075 ...
# 2           0.00        18.00          0.600000           7.940 ...
# 3           0.00        24.00               NaN             NaN ...
# 4           0.00        17.00          1.775000           7.725 ...
#
# label  Phosphate  Platelet Count  Potassium        RDW  Red Blood Cells  \
# 0           4.40      353.500000   3.600000  17.300000         3.075000
# 1           2.70      155.666667   3.100000  13.733333         3.966667
# 2           4.25      247.600000   4.180000  18.960000         2.952000
# 3            NaN      341.000000   3.700000  13.900000         3.980000
# 4           3.30      249.000000   5.066667  16.075000         3.637500
#
# label  Sodium  Specific Gravity  Urea Nitrogen  White Blood Cells   pH
# 0       138.5               NaN      49.500000          35.850000  NaN
# 1       131.5             1.009       8.666667           6.066667  8.0
# 2       137.6             1.017      12.250000          59.300000  6.5
# 3       142.0             1.020      20.000000          16.500000  6.0
# 4       134.0             1.021      28.250000          19.275000  6.0
#
# [5 rows x 37 columns]

# %%
patient_and_admission_data.head()
# Out:
#    subject_id  hadm_id           admittime admission_type insurance  \
# 0         357   122609 2198-11-01 22:36:00      EMERGENCY   Private
# 1         366   134462 2164-11-18 20:27:00      EMERGENCY  Medicare
# 2          94   183686 2176-02-25 16:49:00      EMERGENCY  Medicare
# 3          21   111970 2135-01-30 20:50:00      EMERGENCY  Medicare
# 4         353   108923 2151-03-28 16:01:00      EMERGENCY  Medicare
#
#             ethnicity  death_within_30_days gender        dob  age   age_bins
# 0               WHITE                     0      M 2135-03-22   63   (60, 80]
# 1  HISPANIC OR LATINO                     0      M 2112-05-22   52   (40, 60]
# 2               ASIAN                     0      M 2101-09-20   74   (60, 80]
# 3               WHITE                     1      M 2047-04-04   87  (80, 100]
# 4               WHITE                     0      M 2089-07-23   61   (60, 80]

# %%
#infection_by_specimen_type_per_admission.reset_index(inplace=True)
#infection_by_specimen_type_per_admission.drop(['index'],axis=1,inplace=True)
infection_by_specimen_type_per_admission.columns
# Out:
# Index([   u'subject_id',       u'hadm_id', u'BLOOD CULTURE',   u'MRSA SCREEN',
#               u'SPUTUM',         u'STOOL',          u'SWAB',         u'URINE'],
#       dtype='object', name=u'spec_type_desc')

# %%
num_of_infection_per_patient.head()
# Out:
#    subject_id  hadm_id  num_of_infections
# 0          21   111970                  2
# 1         157   107880                  3
# 2         166   128219                  1
# 3         353   108923                  3
# 4         353   131488                  1

# %%
print "shape of vital data for patient: "  + str(sepsis_festure_list.shape)
print "shape of demographic data: "  + str(patient_and_admission_data.shape)
print "shape of infection by specimen type data: " + str(infection_by_specimen_type_per_admission.shape)
print "shape by num of infection data: " + str(num_of_infection_per_patient.shape)
# Out:
# shape of vital data for patient: (1178, 37)
# shape of demographic data: (1184, 11)
# shape of infection by specimen type data: (663, 8)
# shape by num of infection data: (705, 3)

# %%
Final_sepsis_feature_list = pd.merge(sepsis_festure_list,patient_and_admission_data,on=['subject_id','hadm_id'])
Final_sepsis_feature_list.shape
# Out:
# (1178, 46)

# %% [markdown]
# **Dropping feature that's not needed for Machine Learning models**

# %%
Final_sepsis_feature_list.drop(['admittime','dob','age_bins'], axis = 1, inplace = True)

# %%
Final_sepsis_feature_list.shape
# Out:
# (1178, 43)

# %%
Final_sepsis_feature_list = pd.merge(Final_sepsis_feature_list,infection_by_specimen_type_per_admission,on=['subject_id','hadm_id'],how='left')

# %%
Final_sepsis_feature_list.head()
# Out:
#    subject_id  hadm_id  Alanine Aminotransferase (ALT)  Alkaline Phosphatase  \
# 0          21   111970                       47.000000            167.000000
# 1          94   183686                       90.333333             68.666667
# 2         157   107880                       13.000000            118.000000
# 3         166   128219                             NaN                   NaN
# 4         188   191517                      121.000000            130.000000
#
#    Anion Gap  Asparate Aminotransferase (AST)  Basophils  Bicarbonate  \
# 0       17.0                        82.000000       0.00        23.50
# 1       14.0                        82.333333       0.85        23.25
# 2       17.4                        25.000000       0.00        18.00
# 3       19.0                              NaN       0.00        24.00
# 4       15.0                       114.000000       0.00        17.00
#
#    Bilirubin, Total  Calcium, Total  ...    ethnicity  death_within_30_days  \
# 0          0.300000           7.700  ...        WHITE                     1
# 1          1.033333           8.075  ...        ASIAN                     0
# 2          0.600000           7.940  ...        WHITE                     0
# 3               NaN             NaN  ...        WHITE                     1
# 4          1.775000           7.725  ...        WHITE                     0
#
#    gender  age  BLOOD CULTURE  MRSA SCREEN  SPUTUM  STOOL  SWAB  URINE
# 0       M   87              1            0       0      1     0      0
# 1       M   74            NaN          NaN     NaN    NaN   NaN    NaN
# 2       M   80              0            0       0      0     0      2
# 3       F   91              1            0       0      0     0      0
# 4       M   51            NaN          NaN     NaN    NaN   NaN    NaN
#
# [5 rows x 49 columns]

# %%
Final_sepsis_feature_list = pd.merge(Final_sepsis_feature_list,num_of_infection_per_patient,on=['subject_id','hadm_id'],how='left')

# %%
Final_sepsis_feature_list.shape
# Out:
# (1178, 50)

# %%
Final_sepsis_feature_list.head()
# Out:
#    subject_id  hadm_id  Alanine Aminotransferase (ALT)  Alkaline Phosphatase  \
# 0          21   111970                       47.000000            167.000000
# 1          94   183686                       90.333333             68.666667
# 2         157   107880                       13.000000            118.000000
# 3         166   128219                             NaN                   NaN
# 4         188   191517                      121.000000            130.000000
#
#    Anion Gap  Asparate Aminotransferase (AST)  Basophils  Bicarbonate  \
# 0       17.0                        82.000000       0.00        23.50
# 1       14.0                        82.333333       0.85        23.25
# 2       17.4                        25.000000       0.00        18.00
# 3       19.0                              NaN       0.00        24.00
# 4       15.0                       114.000000       0.00        17.00
#
#    Bilirubin, Total  Calcium, Total        ...          death_within_30_days  \
# 0          0.300000           7.700        ...                             1
# 1          1.033333           8.075        ...                             0
# 2          0.600000           7.940        ...                             0
# 3               NaN             NaN        ...                             1
# 4          1.775000           7.725        ...                             0
#
#    gender  age  BLOOD CULTURE  MRSA SCREEN  SPUTUM  STOOL  SWAB  URINE  \
# 0       M   87              1            0       0      1     0      0
# 1       M   74            NaN          NaN     NaN    NaN   NaN    NaN
# 2       M   80              0            0       0      0     0      2
# 3       F   91              1            0       0      0     0      0
# 4       M   51            NaN          NaN     NaN    NaN   NaN    NaN
#
#    num_of_infections
# 0                  2
# 1                NaN
# 2                  3
# 3                  1
# 4                NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# #### Management of Null values

# %%
Final_sepsis_feature_list.isnull().sum()
# Out:
# subject_id                           0
# hadm_id                              0
# Alanine Aminotransferase (ALT)     177
# Alkaline Phosphatase               192
# Anion Gap                            4
# Asparate Aminotransferase (AST)    177
# Basophils                           52
# Bicarbonate                          4
# Bilirubin, Total                   181
# Calcium, Total                      17
# Chloride                             3
# Creatinine                           2
# Eosinophils                         52
# Glucose                              3
# Hematocrit                           2
# Hemoglobin                           2
# INR(PT)                             60
# Lactate                             80
# Lymphocytes                         52
# MCH                                  2
# MCHC                                 2
# MCV                                  2
# Magnesium                           19
# Monocytes                           52
# Neutrophils                         52
# PT                                  60
# PTT                                 60
# Phosphate                           17
# Platelet Count                       2
# Potassium                            3
# RDW                                  2
# Red Blood Cells                      2
# Sodium                               3
# Specific Gravity                   161
# Urea Nitrogen                        2
# White Blood Cells                    3
# pH                                 144
# admission_type                       0
# insurance                            0
# ethnicity                            0
# death_within_30_days                 0
# gender                               0
# age                                  0
# BLOOD CULTURE                      519
# MRSA SCREEN                        519
# SPUTUM                             519
# STOOL                              519
# SWAB                               519
# URINE                              519
# num_of_infections                  477
# dtype: int64

# %% [markdown]
# **For infection data, replacing null values with zeroes**
#
# Assuming that if no bacteria was found (with or without test), patient didn't have infection.

# %%
Final_sepsis_feature_list['BLOOD CULTURE']=Final_sepsis_feature_list['BLOOD CULTURE'].fillna(0)
Final_sepsis_feature_list['MRSA SCREEN']=Final_sepsis_feature_list['MRSA SCREEN'].fillna(0)
Final_sepsis_feature_list['SPUTUM']=Final_sepsis_feature_list['SPUTUM'].fillna(0)
Final_sepsis_feature_list['STOOL']=Final_sepsis_feature_list['STOOL'].fillna(0)
Final_sepsis_feature_list['SWAB']=Final_sepsis_feature_list['SWAB'].fillna(0)
Final_sepsis_feature_list['URINE']=Final_sepsis_feature_list['URINE'].fillna(0)
Final_sepsis_feature_list['num_of_infections']=Final_sepsis_feature_list['num_of_infections'].fillna(0)

# %% [markdown]
# **For lab reports, replacing null values with mean of valid readings**

# %%
Final_sepsis_feature_list.fillna(Final_sepsis_feature_list.mean(),inplace=True)
# Out:
#       subject_id  hadm_id  Alanine Aminotransferase (ALT)  \
# 0             21   111970                       47.000000
# 1             94   183686                       90.333333
# 2            157   107880                       13.000000
# 3            166   128219                       94.822544
# 4            188   191517                      121.000000
# 5            353   108923                       14.000000
# 6            353   131488                       13.000000
# 7            357   122609                      104.333333
# 8            366   134462                       68.000000
# 9            406   100765                       16.000000
# 10           406   113900                       47.500000
# 11           406   171178                       57.000000
# 12           433   141626                       29.000000
# 13           450   105452                       35.000000
# 14           507   148905                      300.500000
# 15           545   155327                       14.000000
# 16           558   104958                       18.500000
# 17           576   108911                      529.000000
# 18           588   170452                       10.000000
# 19           590   172260                       40.000000
# 20           618   155036                       94.822544
# 21           652   100262                       16.500000
# 22           690   133648                        9.000000
# 23           711   114791                       94.822544
# 24           781   163526                       31.666667
# 25           914   168503                       66.000000
# 26           940   111612                        7.666667
# 27           945   101713                       35.000000
# 28          1026   103873                        7.000000
# 29          1068   174792                       30.000000
# ...          ...      ...                             ...
# 1148       95968   114712                       13.333333
# 1149       96145   161427                       79.500000
# 1150       96240   168044                       58.000000
# 1151       96261   150731                       27.500000
# 1152       96442   107499                       39.333333
# 1153       96553   194204                       17.000000
# 1154       96577   108974                      218.000000
# 1155       96842   125486                       92.000000
# 1156       96962   163165                       94.822544
# 1157       97039   198499                       94.822544
# 1158       97042   186645                       94.822544
# 1159       97143   122472                       21.000000
# 1160       97353   125316                       94.822544
# 1161       97560   128116                       20.000000
# 1162       97801   165472                       94.822544
# 1163       97923   166958                       56.000000
# 1164       97924   100380                       26.000000
# 1165       98220   132856                       23.000000
# 1166       98384   135001                       53.000000
# 1167       98420   123804                       48.500000
# 1168       98435   148017                       14.500000
# 1169       98554   151063                       23.000000
# 1170       98623   107520                      171.000000
# 1171       98698   134977                       10.000000
# 1172       98744   153703                       35.000000
# 1173       98931   185895                       94.822544
# 1174       99299   166418                       94.822544
# 1175       99439   177794                       94.822544
# 1176       99756   172485                       73.000000
# 1177       99973   150202                       94.822544
#
#       Alkaline Phosphatase  Anion Gap  Asparate Aminotransferase (AST)  \
# 0               167.000000  17.000000                        82.000000
# 1                68.666667  14.000000                        82.333333
# 2               118.000000  17.400000                        25.000000
# 3               141.192150  19.000000                       148.710368
# 4               130.000000  15.000000                       114.000000
# 5                44.000000  18.666667                        32.000000
# 6                84.000000  21.750000                        15.000000
# 7               140.666667  13.000000                        96.333333
# 8                90.000000  15.666667                        56.500000
# 9                71.000000  13.500000                        25.000000
# 10              178.500000  16.666667                        51.000000
# 11              190.000000  14.000000                        41.500000
# 12              255.000000  22.750000                        41.000000
# 13              110.000000  17.000000                        58.500000
# 14               95.500000  22.333333                       275.500000
# 15               85.000000  16.600000                        54.000000
# 16               70.000000  20.000000                        23.000000
# 17              131.000000  16.500000                       486.000000
# 18               74.000000  18.666667                        21.000000
# 19              528.000000  14.666667                       144.000000
# 20              141.192150  15.500000                       148.710368
# 21               84.500000  21.333333                        39.500000
# 22               79.000000  14.666667                        17.000000
# 23              141.192150  15.000000                       148.710368
# 24              130.666667  16.600000                        48.666667
# 25              197.000000  15.666667                       155.000000
# 26              236.000000  15.400000                        53.333333
# 27               88.000000  14.000000                        22.000000
# 28               97.000000  15.000000                        19.000000
# 29              109.000000  10.500000                        26.000000
# ...                    ...        ...                              ...
# 1148             61.333333  16.750000                        24.000000
# 1149             91.500000  14.500000                       101.500000
# 1150            198.500000  19.666667                        61.000000
# 1151             89.500000  14.500000                        33.000000
# 1152            148.000000  13.666667                        34.000000
# 1153             65.000000  11.000000                        20.000000
# 1154            233.000000  13.500000                       449.666667
# 1155             59.500000  16.666667                       109.500000
# 1156            141.192150  14.000000                       148.710368
# 1157            141.192150  14.500000                       148.710368
# 1158            141.192150  14.800000                       148.710368
# 1159            155.000000  15.000000                        20.000000
# 1160            141.192150  16.500000                       148.710368
# 1161            141.192150  13.833333                        28.000000
# 1162            141.192150  13.500000                       148.710368
# 1163             90.000000  14.000000                        57.000000
# 1164             87.000000  11.500000                        35.000000
# 1165           1093.000000  14.500000                        48.000000
# 1166             93.500000  18.500000                        65.500000
# 1167             89.000000  15.600000                        40.500000
# 1168             61.000000  13.000000                        34.500000
# 1169             34.000000  14.500000                        28.000000
# 1170             60.500000  13.500000                       108.000000
# 1171             60.666667   9.666667                        13.333333
# 1172            108.000000  20.000000                        88.000000
# 1173            141.192150  12.000000                       148.710368
# 1174            141.192150  16.000000                       148.710368
# 1175            141.192150  14.500000                       148.710368
# 1176            241.000000  20.666667                       112.000000
# 1177            141.192150  13.000000                       148.710368
#
#       Basophils  Bicarbonate  Bilirubin, Total  Calcium, Total  \
# 0      0.000000    23.500000          0.300000        7.700000
# 1      0.850000    23.250000          1.033333        8.075000
# 2      0.000000    18.000000          0.600000        7.940000
# 3      0.000000    24.000000          1.501629        7.903004
# 4      0.000000    17.000000          1.775000        7.725000
# 5      0.200000    28.333333          0.300000        8.766667
# 6      0.000000    24.500000          0.600000        8.933333
# 7      0.200000    16.400000          0.166667        7.260000
# 8      0.000000    25.000000          0.550000        7.900000
# 9      0.100000    16.000000          0.200000        6.200000
# 10     0.100000    22.666667          0.800000        7.900000
# 11     0.000000    16.500000          0.700000        7.025000
# 12     0.000000    20.250000          0.400000        8.766667
# 13     0.300000    20.000000          0.450000        8.400000
# 14     0.000000    14.333333          6.100000        7.850000
# 15     0.600000    18.666667          0.700000        8.300000
# 16     0.650000    21.500000          1.250000        7.950000
# 17     0.000000    18.500000          0.800000        8.100000
# 18     0.400000    24.333333          0.400000        8.733333
# 19     0.000000    17.000000         20.950000        6.750000
# 20     0.100000    18.500000          1.501629        8.000000
# 21     0.000000    13.333333          0.550000        6.860000
# 22     0.200000    29.666667          0.400000        8.800000
# 23     0.300000    20.000000          1.501629        7.500000
# 24     0.000000    22.400000          1.433333        7.275000
# 25     0.000000    21.666667          1.333333        7.700000
# 26     1.000000    24.800000         14.133333        8.000000
# 27     0.000000    21.666667          0.600000        7.350000
# 28     0.100000    24.000000          0.300000        8.150000
# 29     0.187004    24.000000          0.800000        7.000000
# ...         ...          ...               ...             ...
# 1148   0.000000    15.000000          2.000000        6.900000
# 1149   0.187004    17.500000          0.450000        6.900000
# 1150   0.000000    22.333333          2.500000        6.900000
# 1151   0.200000    16.500000          0.500000        7.925000
# 1152   0.000000    18.666667          0.666667        6.950000
# 1153   0.100000    20.666667          0.400000        7.500000
# 1154   0.133333    23.250000          0.366667        6.533333
# 1155   0.100000    20.666667          0.550000        7.233333
# 1156   0.300000    21.000000          1.501629        7.050000
# 1157   1.100000    23.500000          1.501629        7.700000
# 1158   0.500000    23.000000          1.501629        7.800000
# 1159   0.100000    19.500000          0.400000        8.100000
# 1160   0.600000    26.000000          1.501629        7.300000
# 1161   0.000000    17.000000          0.600000        7.400000
# 1162   0.187004    17.000000          1.501629        7.350000
# 1163   0.300000    20.500000          0.500000        7.700000
# 1164   0.300000    22.500000          0.900000        7.900000
# 1165   0.000000    20.500000          3.700000        8.250000
# 1166   0.000000    15.500000          1.300000        7.250000
# 1167   0.650000    14.200000          0.600000        8.225000
# 1168   0.200000    19.333333          0.450000        6.433333
# 1169   0.000000    16.500000          0.500000        7.500000
# 1170   0.100000    25.000000          0.400000        8.150000
# 1171   0.000000    20.000000          0.433333        7.333333
# 1172   0.000000    17.666667          2.100000        7.666667
# 1173   0.187004    26.500000          1.501629        8.200000
# 1174   0.500000    20.500000          1.501629        9.000000
# 1175   1.750000    35.500000          1.501629        8.650000
# 1176   0.187004    19.000000          5.300000        8.966667
# 1177   0.133333    13.000000          1.501629        7.400000
#
#             ...          death_within_30_days  gender  age  BLOOD CULTURE  \
# 0           ...                             1       M   87              1
# 1           ...                             0       M   74              0
# 2           ...                             0       M   80              0
# 3           ...                             1       F   91              1
# 4           ...                             0       M   51              0
# 5           ...                             0       M   61              1
# 6           ...                             0       M   62              1
# 7           ...                             0       M   63              0
# 8           ...                             0       M   52              0
# 9           ...                             0       F   68              0
# 10          ...                             0       F   61              1
# 11          ...                             0       F   62              3
# 12          ...                             0       F   50              0
# 13          ...                             0       F   80              0
# 14          ...                             0       M   75              0
# 15          ...                             0       F   85              0
# 16          ...                             0       M   50              0
# 17          ...                             0       M   88              2
# 18          ...                             0       M   69              1
# 19          ...                             1       M   69              0
# 20          ...                             0       M   78              0
# 21          ...                             0       M   21              0
# 22          ...                             0       M   78              1
# 23          ...                             0       M   84              0
# 24          ...                             0       F   76              2
# 25          ...                             0       M   49              1
# 26          ...                             1       F   63              0
# 27          ...                             0       F   61              0
# 28          ...                             0       F   86              0
# 29          ...                             0       F   77              1
# ...         ...                           ...     ...  ...            ...
# 1148        ...                             1       M   80              1
# 1149        ...                             0       F   75              1
# 1150        ...                             0       M   53              2
# 1151        ...                             0       F   63              0
# 1152        ...                             0       F   45              0
# 1153        ...                             0       M   56              1
# 1154        ...                             0       M   51              0
# 1155        ...                             0       M   82              0
# 1156        ...                             0       F   73              0
# 1157        ...                             0       M   91              0
# 1158        ...                             0       F   87              0
# 1159        ...                             0       M   60              1
# 1160        ...                             0       M   83              0
# 1161        ...                             0       F   91              0
# 1162        ...                             1       M   77              0
# 1163        ...                             0       M   74              0
# 1164        ...                             0       M   81              0
# 1165        ...                             1       M   70              0
# 1166        ...                             1       F   91              0
# 1167        ...                             0       F   59              0
# 1168        ...                             1       F   87              0
# 1169        ...                             0       F   46              0
# 1170        ...                             0       M   45              0
# 1171        ...                             0       M   45              0
# 1172        ...                             0       M   69              0
# 1173        ...                             0       M   55              0
# 1174        ...                             0       F   76              2
# 1175        ...                             0       M   84              0
# 1176        ...                             1       M   51              0
# 1177        ...                             0       F   65              0
#
#       MRSA SCREEN  SPUTUM  STOOL  SWAB  URINE  num_of_infections
# 0               0       0      1     0      0                  2
# 1               0       0      0     0      0                  0
# 2               0       0      0     0      2                  3
# 3               0       0      0     0      0                  1
# 4               0       0      0     0      0                  0
# 5               0       0      0     1      0                  3
# 6               0       0      0     0      0                  1
# 7               0       0      0     0      0                  0
# 8               0       0      0     0      0                  0
# 9               0       0      0     0      0                  0
# 10              0       0      0     0      1                  2
# 11              0       0      0     0      2                  5
# 12              0       0      0     0      0                  0
# 13              0       0      0     0      0                  0
# 14              0       0      0     0      0                  2
# 15              0       0      0     0      0                  0
# 16              0       0      0     0      0                  0
# 17              0       0      0     0      0                  2
# 18              0       0      0     5      0                  6
# 19              0       0      0     0      0                  0
# 20              0       0      0     0      0                  0
# 21              0       0      0     0      0                  1
# 22              0       0      0     0      0                  1
# 23              0       0      0     0      0                  0
# 24              0       0      0     0      0                  3
# 25              0       0      0     0      0                  2
# 26              0       0      0     0      1                  1
# 27              0       0      0     0      1                  1
# 28              0       0      0     0      2                  2
# 29              0       0      0     0      0                  1
# ...           ...     ...    ...   ...    ...                ...
# 1148            0       0      0     0      1                  3
# 1149            0       0      0     0      0                  1
# 1150            0       0      0     0      0                  3
# 1151            0       0      0     0      0                  0
# 1152            0       0      0     0      0                  0
# 1153            1       0      0     0      0                  2
# 1154            0       0      0     0      0                  0
# 1155            0       0      0     0      0                  0
# 1156            0       0      0     0      0                  0
# 1157            1       0      0     0      2                  3
# 1158            1       0      0     0      3                  4
# 1159            0       0      0     2      0                  3
# 1160            0       0      0     0      0                  0
# 1161            0       0      0     0      1                  1
# 1162            1       0      1     0      0                  2
# 1163            0       0      0     0      0                  0
# 1164            0       0      0     0      0                  0
# 1165            0       0      0     0      0                  5
# 1166            0       0      0     0      0                  0
# 1167            0       1      0     0      1                  2
# 1168            0       2      0     0      0                  2
# 1169            0       0      0     0      0                  0
# 1170            0       0      0     0      0                  0
# 1171            0       0      0     0      0                  0
# 1172            0       0      0     0      1                  1
# 1173            0       0      0     2      0                  2
# 1174            0       0      0     0      0                  2
# 1175            0       0      0     0      0                  0
# 1176            0       0      0     0      0                  0
# 1177            0       0      0     0      0                  0
#
# [1178 rows x 50 columns]

# %%
Final_sepsis_feature_list.isnull().sum()
# Out:
# subject_id                         0
# hadm_id                            0
# Alanine Aminotransferase (ALT)     0
# Alkaline Phosphatase               0
# Anion Gap                          0
# Asparate Aminotransferase (AST)    0
# Basophils                          0
# Bicarbonate                        0
# Bilirubin, Total                   0
# Calcium, Total                     0
# Chloride                           0
# Creatinine                         0
# Eosinophils                        0
# Glucose                            0
# Hematocrit                         0
# Hemoglobin                         0
# INR(PT)                            0
# Lactate                            0
# Lymphocytes                        0
# MCH                                0
# MCHC                               0
# MCV                                0
# Magnesium                          0
# Monocytes                          0
# Neutrophils                        0
# PT                                 0
# PTT                                0
# Phosphate                          0
# Platelet Count                     0
# Potassium                          0
# RDW                                0
# Red Blood Cells                    0
# Sodium                             0
# Specific Gravity                   0
# Urea Nitrogen                      0
# White Blood Cells                  0
# pH                                 0
# admission_type                     0
# insurance                          0
# ethnicity                          0
# death_within_30_days               0
# gender                             0
# age                                0
# BLOOD CULTURE                      0
# MRSA SCREEN                        0
# SPUTUM                             0
# STOOL                              0
# SWAB                               0
# URINE                              0
# num_of_infections                  0
# dtype: int64

# %% [markdown]
# **Save the input dataframe to CSV file**
#
# In next iPyhton notebook, I will build machine learning models using this CSV file.

# %%
Final_sepsis_feature_list.to_csv('Final_sepsis_feature_list.csv')

# %% [markdown]
# ## Visualization of data

# %% [markdown]
# Visualization for number of infections

# %%
fig,ax = plt.subplots(figsize=(20,10))
#fig.autofmt_xdate(rotation=90)
g = sns.factorplot(x="num_of_infections", hue="death_within_30_days", data=Final_sepsis_feature_list, kind="count", ax=ax)
#g.set(ylim=(0,100))
ax.legend(bbox_to_anchor=(1, 1), loc=2)
plt.close(2)

# %%
percent_death_within_30_days_by_num_of_infections = Final_sepsis_feature_list.groupby(['death_within_30_days','num_of_infections'])['num_of_infections'].count()

# %%
percent_death_within_30_days_by_num_of_infections=pd.DataFrame(percent_death_within_30_days_by_num_of_infections.groupby(level=[1]).apply(lambda x: x*100 / x.sum()))
percent_death_within_30_days_by_num_of_infections.reset_index(inplace=True)
percent_death_within_30_days_by_num_of_infections.rename(columns={0: 'Percent'}, inplace=True)
percent_death_within_30_days_by_num_of_infections
# Out:
#     death_within_30_days  num_of_infections     Percent
# 0                      0                  0   76.729560
# 1                      0                  1   80.909091
# 2                      0                  2   80.104712
# 3                      0                  3   80.000000
# 4                      0                  4   72.093023
# 5                      0                  5   65.000000
# 6                      0                  6   88.888889
# 7                      0                  7  100.000000
# 8                      0                  8  100.000000
# 9                      0                  9  100.000000
# 10                     0                 10   66.666667
# 11                     0                 11  100.000000
# 12                     0                 14  100.000000
# 13                     1                  0   23.270440
# 14                     1                  1   19.090909
# 15                     1                  2   19.895288
# 16                     1                  3   20.000000
# 17                     1                  4   27.906977
# 18                     1                  5   35.000000
# 19                     1                  6   11.111111
# 20                     1                 10   33.333333

# %%
g = sns.factorplot(x="num_of_infections", y="Percent", hue="death_within_30_days",
...                    data=percent_death_within_30_days_by_num_of_infections, saturation=.5,
...                    kind="bar", ci=8, aspect=2)
g.set(ylim=(0,100))

# %% [markdown]
# Visualization by Specimen Type

# %%
data_by_specimen_type = Final_sepsis_feature_list[['death_within_30_days','BLOOD CULTURE','MRSA SCREEN','SPUTUM','STOOL','SWAB','URINE']]

# %%
data_by_specimen_type = data_by_specimen_type.groupby(['death_within_30_days']).sum()

# %%
data_by_specimen_type.reset_index(inplace=True)
data_by_specimen_type
# Out:
#    death_within_30_days  BLOOD CULTURE  MRSA SCREEN  SPUTUM  STOOL  SWAB  \
# 0                     0            312           42     174     33   178
# 1                     1             89            4      61     11    19
#
#    URINE
# 0    274
# 1     58

# %%
data_by_specimen_type = pd.melt(data_by_specimen_type, id_vars=['death_within_30_days'], value_vars=['BLOOD CULTURE','MRSA SCREEN','SPUTUM','STOOL','SWAB','URINE'],
...         var_name='Specimen Type', value_name='Count')
data_by_specimen_type
# Out:
#     death_within_30_days  Specimen Type  Count
# 0                      0  BLOOD CULTURE    312
# 1                      1  BLOOD CULTURE     89
# 2                      0    MRSA SCREEN     42
# 3                      1    MRSA SCREEN      4
# 4                      0         SPUTUM    174
# 5                      1         SPUTUM     61
# 6                      0          STOOL     33
# 7                      1          STOOL     11
# 8                      0           SWAB    178
# 9                      1           SWAB     19
# 10                     0          URINE    274
# 11                     1          URINE     58

# %%
g = sns.factorplot(x="Specimen Type", y="Count", hue="death_within_30_days",
...                    data=data_by_specimen_type, saturation=.5,
...                    kind="bar", ci=8, aspect=2)

# %%
data_by_specimen_type
# Out:
#     death_within_30_days  Specimen Type  Count
# 0                      0  BLOOD CULTURE    312
# 1                      1  BLOOD CULTURE     89
# 2                      0    MRSA SCREEN     42
# 3                      1    MRSA SCREEN      4
# 4                      0         SPUTUM    174
# 5                      1         SPUTUM     61
# 6                      0          STOOL     33
# 7                      1          STOOL     11
# 8                      0           SWAB    178
# 9                      1           SWAB     19
# 10                     0          URINE    274
# 11                     1          URINE     58

# %%
data_by_specimen_type = data_by_specimen_type.groupby(['Specimen Type','death_within_30_days']).agg({'Count': 'sum'})
data_by_specimen_type['percent'] = data_by_specimen_type.groupby(level=0).apply((lambda x: x*100 / x.sum()))
data_by_specimen_type.reset_index(inplace=True)
data_by_specimen_type
# Out:
#     Specimen Type  death_within_30_days  Count    percent
# 0   BLOOD CULTURE                     0    312  77.805486
# 1   BLOOD CULTURE                     1     89  22.194514
# 2     MRSA SCREEN                     0     42  91.304348
# 3     MRSA SCREEN                     1      4   8.695652
# 4          SPUTUM                     0    174  74.042553
# 5          SPUTUM                     1     61  25.957447
# 6           STOOL                     0     33  75.000000
# 7           STOOL                     1     11  25.000000
# 8            SWAB                     0    178  90.355330
# 9            SWAB                     1     19   9.644670
# 10          URINE                     0    274  82.530120
# 11          URINE                     1     58  17.469880

# %%
g = sns.factorplot(x="Specimen Type", y="percent", hue="death_within_30_days",
...                    data=data_by_specimen_type, saturation=.5,
...                    kind="bar", ci=8, aspect=2)
g.set(ylim=(0,100))
